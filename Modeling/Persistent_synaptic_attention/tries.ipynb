# %%
# %run model_psa.py
# Out:
# New vers

# %%
# %run hello.py
# Out:
# What??

# %%
## 1_02 
model(totalTime=6200, targ_onset = 200, dist_onset=550, 
      presentation_period=250, separation=3, 
      inhib_curr=False, time_ex_input=0,  sigE=1.2, 
      plot_connectivity=False, plot_dyniamic=True, 
      plot_heatmap=True, plot_fit=True )
# Out:
# Simulation time: 67.7s
# (-1.07, 0, 1, 120.0)

# %%
model(totalTime=6200, targ_onset = 200, dist_onset=550, 
      presentation_period=250, separation=3, 
      inhib_curr=False, time_ex_input=0,  sigE=1.2, 
      plot_connectivity=False, plot_dyniamic=True, 
      plot_heatmap=True, plot_fit=True )

# %%
## 1_7 
model(totalTime=6200, targ_onset = 200, dist_onset=3950, 
      presentation_period=250, separation=3, 
      inhib_curr=False, time_ex_input=0,  sigE=1.2, 
      plot_connectivity=False, plot_dyniamic=True, 
      plot_heatmap=True, plot_fit=True )
# Out:
# Simulation time: 76.1s
# (-1.09, 0, 1, 120.0)

# %%
## 2_0.2
model(totalTime=6200, targ_onset = 550, dist_onset=200,
      presentation_period=250, separation=3, 
      inhib_curr=True, time_ex_input=0,  sigE=1.2, 
      plot_connectivity=False, plot_dyniamic=True, 
      plot_heatmap=True, plot_fit=True )
# Out:
# Simulation time: 73.1s
# (-0.36, 0, 1, 120.0)

# %%
## 2_7 
model(totalTime=9600, targ_onset = 3950, dist_onset=200, 
      presentation_period=250, separation=3, 
      inhib_curr=True, time_ex_input=0,  sigE=1.2, 
      plot_connectivity=False, plot_dyniamic=True, 
      plot_heatmap=True, plot_fit=True )
# Out:
# Simulation time: 114.5s
# (9.45, -49.57, 2, 120.0)
