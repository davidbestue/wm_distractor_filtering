# %%
from math import floor, exp, sqrt, pi
import cmath
import numpy
from numpy import e, cos, zeros, arange, roll, where, random, ones, mean, reshape, dot, array, flipud, pi, exp, dot, angle, degrees, shape, linspace
import matplotlib.pyplot as plt
from itertools import chain
import scipy
from scipy import special
import numpy as np 
import seaborn as sns
import time
from joblib import Parallel, delayed
import multiprocessing
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import scipy.signal
from scipy.optimize import curve_fit 


numcores = multiprocessing.cpu_count()-3
numcores


def decode_rE(rE, a_ini=0, a_fin=360, N=512):
    #Population vector for a given rE
    # return ( angle in radians, absolut angle in radians, abs angle in degrees )
    N=len(rE)
    Angles = np.linspace(a_ini, a_fin, N) 
    angles=np.radians(Angles)
    rE = np.reshape(rE, (1,N))
    R = numpy.sum(np.dot(rE,exp(1j*angles)))/numpy.sum(rE)
    
    angle_decoded = np.degrees(np.angle(R))
    if angle_decoded<0:
        angle_decoded = 360+angle_decoded
    
    return angle_decoded
    #Mat.append(  [angle(R), abs(angle(R)) , degrees(abs(angle(R)))]  )
    #return round( np.degrees(abs(np.angle(R))), 2)





def circ_dist(a1,a2):
    ## Returns the minimal distance in angles between to angles 
    op1=abs(a2-a1)
    angs=[a1,a2]
    op2=min(angs)+(360-max(angs))
    options=[op1,op2]
    return min(options)


def most_frequent(List): 
    dict = {} 
    count, itm = 0, '' 
    for item in reversed(List): 
        dict[item] = dict.get(item, 0) + 1
        if dict[item] >= count : 
            count, itm = dict[item], item 
    return(itm) 


def Interference_effects(target, response, reference):
    #input list of target, list of responses and list of references
    #Error_interference; positive for attraction and negative for repulsion
    #######
    #Decimals to get
    decimals=2
    ####
    interferences=[]
    for i in range(0, len(target)):
        angle_err_abs=abs(target[i] - response[i])
        if circ_dist(np.array(response)[i], np.array(reference)[i])<=circ_dist(np.array(target)[i], np.array(reference)[i]):
            Err_interference=round( angle_err_abs, decimals) 
        else:
            Err_interference=round( -angle_err_abs, decimals)
        interferences.append(Err_interference)
    
    return interferences


def viz_polymonial(X, y, poly_reg, pol_reg):
    plt.figure()
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Fit Bump')
    plt.xlabel('Neuron')
    plt.ylabel('rate')
    plt.show(block=False)
    return




def simulation(totalTime, targ_onset, dist_onset, presentation_period, separation, 
               tauE=60, tauI=10, tauf=7000, taud=80, I0E=1.3, I0I=0.4, U=0.4,
               GEE=0.016, GEI=0.015, GIE=0.012 , GII=0.007, sigE=0.06, sigI=0.04,
               kappa_E=100, kappa_I=1.5, k_inhib=0.07, kappa_stim=20,
               N=512, plot_connectivity=True, plot_dyniamic=True, plot_heatmap=True, plot_fit=True ):
    
    ###### temporal and spatial settings
    st_sim =time.time()
    dt=2;
    nsteps=int(floor(totalTime/dt));
    origin = pi;
    targ_offset = targ_onset + presentation_period;
    targon = floor(targ_onset/dt);
    targoff = floor(targ_offset/dt);
    
    dist_offset = dist_onset  + presentation_period;
    diston = floor(dist_onset/dt);
    distoff = floor(dist_offset/dt);
    stim_sep = pi/separation; #(13 attract, 9 solo 1, 5 repulsion, 2 nada)
    
    targ_dist_delay = dist_onset - targ_offset
    
    ###### Connectivities
    v_E=np.zeros((N));
    v_I=np.zeros((N));
    WE=np.zeros((N,N));
    WI=np.zeros((N,N));
    theta = [float(range(0,N)[i])/N*2*pi for i in range(0,N)];
    for i in range(0, N):
        v_E_new=[e**(kappa_E*cos(theta[f]))/(2*pi*scipy.special.i0(kappa_E)) for f in range(0, len(theta))]    
        v_I_new=[e**(kappa_I*cos(theta[f]))/(2*pi*scipy.special.i0(kappa_I)) + k_inhib for f in range(0, len(theta))] #0.18
        ###    
        vE_NEW=np.roll(v_E_new,i)
        vI_NEW=np.roll(v_I_new,i) #to roll
        ###    
        WE[:,i]=vE_NEW
        WI[:,i]=vI_NEW
    ##
    # Plot of the connectivity profile
    if plot_connectivity ==True:
        plt.figure()
        plt.plot(WE[250, :], label='E')
        plt.plot(WI[250, :], label = 'I')
        plt.ylim(0,6)
        plt.gca().spines['right'].set_visible(False) #no right axis
        plt.gca().spines['top'].set_visible(False) #no  top axis
        plt.gca().get_xaxis().tick_bottom()
        plt.gca().get_yaxis().tick_left()
        plt.title('Connectivity WE & WI')
        plt.show(block=False)
        plt.figure()
        plt.plot(WE[250, :] - WI[250, :] , label='E-I')
        #plt.plot(WI[250, :], label = 'I')
        #plt.ylim(0,6)
        plt.gca().spines['right'].set_visible(False) #no right axis
        plt.gca().spines['top'].set_visible(False) #no  top axis
        plt.gca().get_xaxis().tick_bottom()
        plt.gca().get_yaxis().tick_left()
        plt.title('Effective onnectivity')
        plt.show(block=False)
    #topography_pattern  =  WE[250, :] + -1*(WI[250, :]) ##plot the topography of the connectivities
    #plt.plot(topography_pattern, 'k')
    #plt.show(block=False)
    
    ###### Stimuli
    target=np.zeros((N))
    distractor=np.zeros((N))
    for i in range(0, N):
        target[i]=e**(kappa_stim*cos(theta[i] + origin - stim_sep)) / (2*pi*scipy.special.i0(kappa_stim)) 
        distractor[i]=e**(kappa_stim*cos(theta[i] + origin + stim_sep)) / (2*pi*scipy.special.i0(kappa_stim)) 


    target = target+ np.random.normal(0, 0.01, N)
    target=reshape(target, (N,1))
    distractor = distractor+ np.random.normal(0, 0.01, N)
    distractor=reshape(distractor, (N,1)) 
    
    #plt.plot(target) ##plot the target and distractor
    #plt.plot(distractor)
    #plt.show(block=False)
    
    ###### Model   
    rE=np.zeros((N,1));
    rI=np.zeros((N,1)); 
    u = np.ones((N,1))*U
    x = np.ones((N,1))
    RE=np.zeros((N,nsteps));
    RI=np.zeros((N,nsteps));
    p_u=np.ones((N,nsteps));
    p_x=np.ones((N,nsteps));
    
    f = lambda x : x*x*(x>0)*(x<1) + reshape(array([cmath.sqrt(4*x[i]-3) for i in range(0, len(x))]).real, (N,1)) * (x>=1)
    
    ### diferential equations
    for i in range(0, nsteps):
        noiseE = sigE*random.randn(N,1);
        noiseI = sigI*random.randn(N,1);

        #differential equations for connectivity
        IE= GEE*dot(WE, (rE*u*x)) - GIE*dot(WI,rI) + I0E*ones((N,1)); 
        II= GEI*dot(WE,rE) +  (I0I-GII*mean(rI))*ones((N,1));

        if i>targon and i<targoff:
            IE=IE+target;
            II=II+target;

        if i>diston and i<distoff:
            IE=IE+distractor;
            II=II+distractor;


        #rates of exit and inhib   
        rE = rE + (f(IE) - rE + noiseE)*dt/tauE;
        rI = rI + (f(II) - rI + noiseI)*dt/tauI;
        ### formulas for synaptic plasticity: paper mongillo 2008
        u = u + ((U - u) / tauf + U*(1-u)*rE/1000)*dt;
        x = x + ((1 - x)/taud - u*x*rE/1000)*dt;
        
        rEr=np.reshape(rE, N)
        rIr=np.reshape(rI, N)
        ur=np.reshape(u, N)
        xr=np.reshape(x, N)
        #append
        RE[:,i] = rEr;
        RI[:,i] = rIr;
        p_u[:,i] = ur;
        p_x[:,i] = xr;
    
    
    #### Interference
    interference = Interference_effects( [decode_rE(target)], [decode_rE(rE)], [decode_rE(distractor)])[0] ## just one bump
    p_targ = int((N * np.degrees(origin + stim_sep))/360)
    
    if plot_dyniamic==True:
        #### plot dynamics
        fig = plt.figure()
        fig.tight_layout()
        fig.set_size_inches(13, 4)
        fig.add_subplot(131)
        p_targ = int((N * np.degrees(origin + stim_sep))/360)
        plt.title('Synaptic dynamics for target')
        plt.plot(p_u[p_targ, :], 'b', label='prob. release')
        plt.plot(p_x[p_targ, :], 'r', label='pool vesicles')
        plt.xlabel('time (ms)')
        plt.legend()
        fig.add_subplot(132)
        p_dist= int((N * np.degrees(origin - stim_sep))/360)
        plt.title('Synaptic dynamics for distractor')
        plt.plot(p_u[p_dist, :], 'b', label='prob.y release')
        plt.plot(p_x[p_dist, :], 'r', label='pool vesicles')
        plt.xlabel('time (ms)')
        plt.legend()
        fig.add_subplot(133)
        plt.title('Rate dynamics')
        plt.plot(RE[p_targ, :], 'b', label='target')
        plt.plot(RE[p_dist, :], 'r', label='distractor')
        plt.xlabel('time (ms)')
        plt.ylabel('rate (Hz)')
        plt.legend()
        plt.show(block=False)
    #
    if plot_heatmap==True:
        #### plot heatmap
        RE_sorted=flipud(RE)
        p_dist= int((N * np.degrees(origin - stim_sep))/360)
        plt.figure(figsize=(9,6))
        sns.heatmap(RE_sorted, cmap='viridis')
        plt.title('BUMP activity')
        plt.ylabel('Angle')
        plt.xlabel('time')
        plt.plot([targon, nsteps], [p_dist, p_dist], '--b',) ## flipped, so it is p_target 
        plt.plot([diston, nsteps], [p_targ, p_targ], '--r',) ## flipped, so it is p_target 
        plt.yticks([])
        plt.xticks([])
        plt.yticks([N/8, 3*N/8, 5*N/8, 7*N/8 ] ,['45','135','225', '315'])
        plt.plot([targ_onset/2, targ_onset/2,], [0+20, N-20], 'k-', label='onset')
        plt.plot([targ_offset/2, targ_offset/2,], [0+20, N-20], 'k--', label='offset')
        plt.plot([dist_onset/2, dist_onset/2,], [0+20, N-20], 'k-')
        plt.plot([dist_offset/2, dist_offset/2,], [0+20, N-20], 'k--')
        plt.legend()
        plt.show(block=False)
    
    
    ## print time consumed
    end_sim =time.time()
    total_time= end_sim - st_sim 
    total_time = round(total_time, 1)
    print('Simulation time: ' + str(total_time) + 's')
    
    
    #### Fit
        ###### Fit
    def von_misses(x,mu,k):
        return (exp( k * cos(x-mu))) / (2*pi*scipy.special.i0(k)) 

    def bi_von_misses(x,mu1,k1,mu2,k2):
        return von_misses(x,mu1,k1) + von_misses(x,mu2,k2)

    ##
    y=np.reshape(rE, (N)) 
    X=np.reshape(np.linspace(-pi, pi, N), N)

    ### Fit
    df_n_p=pd.DataFrame()
    df_n_p['rE'] = rE.reshape(512)
    peaks_list=[]
    for n_w_s in range(1, 100):
        r = df_n_p['rE'].rolling(window=n_w_s).mean()
        number_of_bumps = len(scipy.signal.find_peaks(r, 2)[0]) 
        peaks_list.append(number_of_bumps)
    #
    if number_of_bumps == 0:
        if peaks_list==[0 for i in range(len(peaks_list))]:
            number_of_bumps = 0
        else:
            peaks_list[:] = (value for value in peaks_list if value != 0)
            number_of_bumps=most_frequent(peaks_list)
    #
    number_of_bumps=most_frequent(peaks_list)
    #print(number_of_bumps)
    number_of_bumps = 2


    ### Fit
    if number_of_bumps ==2:
        param, covs = curve_fit(bi_von_misses, X, y, p0=[separation, 75, -separation, 75])
        ans = (exp( param[1] * cos(X-param[0]))) / (2*pi*scipy.special.i0(param[1])) + (exp( param[3] * cos(X-param[2]))) / (2*pi*scipy.special.i0(param[3])) 
        estimated_angles=[]
        for p in [param[0], param[2]]:
            estim_ang = np.degrees(p)
            if estim_ang<0:
                estim_ang = 360+estim_ang
            estimated_angles.append(estim_ang)
        
        #          
        estimated_angle_1=estimated_angles[0]
        estimated_angle_2=estimated_angles[1]
        #print(estimated_angle_1, estimated_angle_2)
        estimated_angles = [estimated_angle_1, estimated_angle_2]
        #estimated_angles.sort()
        #
        
        
        ### wich one is the target and which the distractor?????
        
        
        min_bias = min(  abs(np.degrees( origin + pi/separation) - estimated_angle_1 ), abs( np.degrees( origin - pi/separation) - estimated_angle_1  ) )
        if min_bias == abs(np.degrees( origin + pi/separation) - estimated_angle_1 ):
            dist_ang = estimated_angle_1
            targ_ang = estimated_angle_2
            #bias_b1 = np.degrees( origin + pi/separation) -  estimated_angle_1 
            #bias_b2 = np.degrees( origin - pi/separation) -  estimated_angle_2 
            ####
            #bias_dist = Interference_effects(  [np.degrees( origin + pi/separation)],  [dist_ang],  [np.degrees( origin - pi/separation)])[0]
            #bias_target = Interference_effects(  [np.degrees( origin - pi/separation)],  [targ_ang],  [np.degrees( origin + pi/separation)])[0]
            #
            bias_dist = Interference_effects(  [decode_rE(target)],  [dist_ang],  [decode_rE(distractor)])[0]
            bias_target = Interference_effects(  [decode_rE(distractor)],  [targ_ang],  [decode_rE(target)])[0]
            

        else:
            targ_ang = estimated_angle_1
            dist_ang = estimated_angle_2
            #bias_b1 = np.degrees( origin - pi/separation) -  estimated_angle_1 
            #bias_b2 = np.degrees( origin + pi/separation) -  estimated_angle_2 
            ####
            #decode_rE(target)
            #bias_target = Interference_effects(  [np.degrees( origin - pi/separation)],  [targ_ang],  [np.degrees( origin + pi/separation)])[0]
            #bias_dist = Interference_effects(  [np.degrees( origin + pi/separation)],  [dist_ang],  [np.degrees( origin - pi/separation)])[0]
            ##
            bias_target = Interference_effects(  [decode_rE(distractor)],  [targ_ang],  [decode_rE(target)])[0]
            bias_dist = Interference_effects(  [decode_rE(target)],  [dist_ang],  [decode_rE(distractor)])[0]
            
            ##
        
        ###
        #print('target',round(targ_ang,2), round(decode_rE(distractor), 2), round(bias_target,2))
        #print('distractor', round(dist_ang,2), round(decode_rE(target),2), round(bias_dist,2))
        final_bias = [bias_target, bias_dist]
        skip_r_sq=False
        success=True
        #print(np.degrees( origin - pi/separation), decode_rE(target))
        #print(np.degrees( origin + pi/separation), decode_rE(distractor))
        #print(targ_ang, dist_ang)

    elif number_of_bumps ==1:
        param, covs = curve_fit(von_misses, X, y)
        ans = (exp( param[1] * cos(X-param[0]))) / (2*pi*scipy.special.i0(param[1])) 
        estimated_angle=np.degrees(param[0]+pi)  
        
        min_bias = min(  abs(estimated_angle - np.degrees( origin + pi/separation)), 
                       abs(estimated_angle - np.degrees( origin - pi/separation))  )
        if min_bias == abs(estimated_angle - np.degrees( origin + pi/separation)):
            bias_b1 = estimated_angle - np.degrees( origin + pi/separation)
            bias_b2 = estimated_angle - np.degrees( origin - pi/separation)
        else:
            bias_b1 = estimated_angle - np.degrees( origin - pi/separation)
            bias_b2 = estimated_angle - np.degrees( origin + pi/separation)
        ##
        #bias_b1 = estimated_angle - np.degrees( origin - pi/separation)
        #bias_b2 = np.degrees(origin + pi/separation) - estimated_angle  ## bias (positive means attraction)
        final_bias = [bias_b1, bias_b2]  
        skip_r_sq=False
        success=True

    else:
        print('Error simultaion')
        final_bias=[999, 999]
        plot_fit=False
        skip_r_sq=True
        r_squared=0
        success=False ## to eliminate wrong simulations easily at the end

    #error_fit (r_squared)
    if skip_r_sq==False:
        residuals = y - ans
        ss_res = np.sum(residuals**2)
        ss_tot = np.sum((y-numpy.mean(y))**2)
        r_squared = 1 - (ss_res / ss_tot)

    #plot fit
    if plot_fit==True:
        plt.figure()
        plt.plot(X, y, 'o', color ='red', label ="data") 
        plt.plot(X, ans, '--', color ='blue', label ="fit") 
        plt.legend() 
        plt.show(block=False) 
    
    ### Output
    #return RE,  RI, p_u, p_x
    #return interference, targ_dist_delay 
    max_re = max(rE)[0]
    ### interfernce max
    dec_far = np.linspace(180,0,int(N/2))[np.where(y[int(N/2):]==max(y[int(N/2):]))[0][0]]
    #dec_close = np.linspace(180,0,int(N/2))[np.where(y1[int(N/2):]==max(y1[int(N/2):]))[0][0]]
    #int_close = dec_close - np.degrees( pi - pi/4)
    int_far = dec_far - np.degrees( pi - pi/4)
    
    return int_far, max_re, bias_dist, bias_target,  number_of_bumps, targ_ang, dist_ang, X, y #rE[p_targ][0], I0E

# %% [markdown]
# ***Simulation 1_02***

# %%
for i in range(7):
    interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y1  = simulation(totalTime=6450, 
                                                                                                          targ_onset = 200, 
                                                                                                          dist_onset=450+100 , 
                                                                                                          presentation_period=250, 
                                                                                                          separation=3, sigE=0.7,
                                                                                                          plot_connectivity=False,
                                                                                                          plot_dyniamic=True,
                                                                                                          plot_heatmap=True, 
                                                                                                          plot_fit=True,
                                                                                                          GEE=0.016)

    ##

    print(interference, bias_target, bias_dist)

# %%
### plot target and distractor on top of fit

# %% [markdown]
# ***Simulation 1_7***

# %%
interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y  = simulation(totalTime=6450, 
                                                                                                      targ_onset = 200, 
                                                                                                      dist_onset=450+3500 , 
                                                                                                      presentation_period=250, 
                                                                                                      separation=4, sigE=0.7,
                                                                                                      plot_connectivity=False,
                                                                                                      plot_dyniamic=True,
                                                                                                      plot_heatmap=True, 
                                                                                                      plot_fit=True, 
                                                                                                      GEE=0.016)

print(interference, bias_target, bias_dist)
# Out:
# Simulation time: 61.6s
# -2.2941176470588402 -2.2 -5.18

# %%
# N=512
# plt.plot(np.linspace(180,0,int(N/2)),y[int(N/2):], label='far')
# plt.plot(np.linspace(180,0,int(N/2)), y1[int(N/2):], label='close')
# plt.legend()


# dec_far = np.linspace(180,0,int(N/2))[np.where(y[int(N/2):]==max(y[int(N/2):]))[0][0]]
# dec_close = np.linspace(180,0,int(N/2))[np.where(y1[int(N/2):]==max(y1[int(N/2):]))[0][0]]
# int_close = dec_close - np.degrees( pi - pi/4)
# int_far = dec_far - np.degrees( pi - pi/4)

# %%
def simulation_2_7(totalTime, targ_onset, dist_onset, presentation_period, separation, inhib_curr,
               time_ex_input=10, tauE=60, tauI=10, tauf=7000, taud=80, I0E=1.3, I0I=0.4, U=0.4,
               GEE=0.0165, GEI=0.015, GIE=0.012 , GII=0.007, sigE=0.06, sigI=0.04,
               kappa_E=100, kappa_I=1.5, k_inhib=0.07, kappa_stim=20,
               N=512, plot_connectivity=True, plot_dyniamic=True, plot_heatmap=True, plot_fit=True ):
    
    ###### temporal and spatial settings
    st_sim =time.time()
    dt=2;
    nsteps=int(floor(totalTime/dt));
    origin = pi;
    targ_offset = targ_onset + presentation_period;
    targon = floor(targ_onset/dt);
    targoff = floor(targ_offset/dt);
    
    dist_offset = dist_onset  + presentation_period;
    diston = floor(dist_onset/dt);
    distoff = floor(dist_offset/dt);
    stim_sep = pi/separation; #(13 attract, 9 solo 1, 5 repulsion, 2 nada)
    
    targ_dist_delay = dist_onset - targ_offset
    
    if inhib_curr == True:
        I0E_open = I0E
        I0E_close=I0E_open-0.9
        I0E = I0E_close    
    
    ###### Connectivities
    v_E=np.zeros((N));
    v_I=np.zeros((N));
    WE=np.zeros((N,N));
    WI=np.zeros((N,N));
    theta = [float(range(0,N)[i])/N*2*pi for i in range(0,N)];
    for i in range(0, N):
        v_E_new=[e**(kappa_E*cos(theta[f]))/(2*pi*scipy.special.i0(kappa_E)) for f in range(0, len(theta))]    
        v_I_new=[e**(kappa_I*cos(theta[f]))/(2*pi*scipy.special.i0(kappa_I)) + k_inhib for f in range(0, len(theta))] #0.18
        ###    
        vE_NEW=np.roll(v_E_new,i)
        vI_NEW=np.roll(v_I_new,i) #to roll
        ###    
        WE[:,i]=vE_NEW
        WI[:,i]=vI_NEW
    
    #
    # Plot of the connectivity profile
    if plot_connectivity ==True:
        plt.figure()
        plt.plot(WE[250, :], label='E')
        plt.plot(WI[250, :], label = 'I')
        plt.ylim(0,6)
        plt.gca().spines['right'].set_visible(False) #no right axis
        plt.gca().spines['top'].set_visible(False) #no  top axis
        plt.gca().get_xaxis().tick_bottom()
        plt.gca().get_yaxis().tick_left()
        plt.title('Connectivity WE & WI')
        plt.show(block=False)
        plt.figure()
        plt.plot(WE[250, :] - WI[250, :] , label='E-I')
        #plt.plot(WI[250, :], label = 'I')
        #plt.ylim(0,6)
        plt.gca().spines['right'].set_visible(False) #no right axis
        plt.gca().spines['top'].set_visible(False) #no  top axis
        plt.gca().get_xaxis().tick_bottom()
        plt.gca().get_yaxis().tick_left()
        plt.title('Effective onnectivity')
        plt.show(block=False)
    
    #topography_pattern  =  WE[250, :] + -1*(WI[250, :]) ##plot the topography of the connectivities
    #plt.plot(topography_pattern, 'k')
    #plt.show(block=False)
    
    ###### Stimuli
    target=np.zeros((N))
    distractor=np.zeros((N))
    for i in range(0, N):
        target[i]=e**(kappa_stim*cos(theta[i] + origin - stim_sep)) / (2*pi*scipy.special.i0(kappa_stim)) 
        distractor[i]=e**(kappa_stim*cos(theta[i] + origin + stim_sep)) / (2*pi*scipy.special.i0(kappa_stim)) 


    target = target+ np.random.normal(0, 0.01, N)
    target=reshape(target, (N,1))
    distractor = distractor+ np.random.normal(0, 0.01, N)
    distractor=reshape(distractor, (N,1)) 
    
    #plt.plot(target) ##plot the target and distractor
    #plt.plot(distractor)
    #plt.show(block=False)
    
    ###### Model   
    rE=np.zeros((N,1));
    rI=np.zeros((N,1)); 
    u = np.ones((N,1))*U
    x = np.ones((N,1))
    RE=np.zeros((N,nsteps));
    RI=np.zeros((N,nsteps));
    p_u=np.ones((N,nsteps));
    p_x=np.ones((N,nsteps));
    
    f = lambda x : x*x*(x>0)*(x<1) + reshape(array([cmath.sqrt(4*x[i]-3) for i in range(0, len(x))]).real, (N,1)) * (x>=1)
    
    ### diferential equations
    for i in range(0, nsteps):
        noiseE = sigE*random.randn(N,1);
        noiseI = sigI*random.randn(N,1);

        #differential equations for connectivity
        IE= GEE*dot(WE, (rE*u*x)) - GIE*dot(WI,rI) + I0E*ones((N,1)); 
        II= GEI*dot(WE,rE) +  (I0I-GII*mean(rI))*ones((N,1));

        if i>targon and i<targoff:
            IE=IE+target;
            II=II+target;

        if i>diston and i<distoff:
            IE=IE+distractor;
            II=II+distractor;
        
        if inhib_curr == True:            
            if i > distoff and i< distoff +200:
                I0E=I0E_open
                
            if i > distoff+200 and i< targon-500 :
                I0E=I0E_close
                
            if i > targon-500 :
                I0E=I0E_open
        
        ###
        #rates of exit and inhib   
        rE = rE + (f(IE) - rE + noiseE)*dt/tauE;
        rI = rI + (f(II) - rI + noiseI)*dt/tauI;
        ### formulas for synaptic plasticity: paper mongillo 2008
        u = u + ((U - u) / tauf + U*(1-u)*rE/1000)*dt;
        x = x + ((1 - x)/taud - u*x*rE/1000)*dt;
        
        rEr=np.reshape(rE, N)
        rIr=np.reshape(rI, N)
        ur=np.reshape(u, N)
        xr=np.reshape(x, N)
        #append
        RE[:,i] = rEr;
        RI[:,i] = rIr;
        p_u[:,i] = ur;
        p_x[:,i] = xr;
    
    
    #### Interference
    interference = Interference_effects( [decode_rE(target)], [decode_rE(rE)], [decode_rE(distractor)])[0]
    p_targ = int((N * np.degrees(origin + stim_sep))/360)
    if plot_dyniamic==True:
        #### plot dynamics
        fig = plt.figure()
        fig.tight_layout()
        fig.set_size_inches(13, 4)
        fig.add_subplot(131)
        p_targ = int((N * np.degrees(origin + stim_sep))/360)
        plt.title('Synaptic dynamics for target')
        plt.plot(p_u[p_targ, :], 'b', label='prob. release')
        plt.plot(p_x[p_targ, :], 'r', label='pool vesicles')
        plt.xlabel('time (ms)')
        plt.legend()
        fig.add_subplot(132)
        p_dist= int((N * np.degrees(origin - stim_sep))/360)
        plt.title('Synaptic dynamics for distractor')
        plt.plot(p_u[p_dist, :], 'b', label='prob.y release')
        plt.plot(p_x[p_dist, :], 'r', label='pool vesicles')
        plt.xlabel('time (ms)')
        plt.legend()
        fig.add_subplot(133)
        plt.title('Rate dynamics')
        plt.plot(RE[p_targ, :], 'b', label='target')
        plt.plot(RE[p_dist, :], 'r', label='distractor')
        plt.xlabel('time (ms)')
        plt.ylabel('rate (Hz)')
        plt.legend()
        plt.show(block=False)
    #
    if plot_heatmap==True:
        #### plot heatmap
        p_dist= int((N * np.degrees(origin - stim_sep))/360)
        RE_sorted=flipud(RE)
        plt.figure(figsize=(9,6))
        sns.heatmap(RE_sorted, cmap='viridis')
        plt.title('BUMP activity')
        plt.ylabel('Angle')
        plt.xlabel('time')
        plt.plot([targon, nsteps], [p_dist, p_dist], '--b',) ## flipped, so it is p_target 
        plt.plot([diston, nsteps], [p_targ, p_targ], '--r',) ## flipped, so it is p_target 
        plt.yticks([])
        plt.xticks([])
        plt.yticks([N/8, 3*N/8, 5*N/8, 7*N/8 ] ,['45','135','225', '315'])
        plt.plot([targ_onset/2, targ_onset/2,], [0+20, N-20], 'k-', label='onset')
        plt.plot([targ_offset/2, targ_offset/2,], [0+20, N-20], 'k--', label='offset')
        plt.plot([dist_onset/2, dist_onset/2,], [0+20, N-20], 'k-')
        plt.plot([dist_offset/2, dist_offset/2,], [0+20, N-20], 'k--')
        plt.legend()
        plt.show(block=False)
    
    
    ## print time consumed
    end_sim =time.time()
    total_time= end_sim - st_sim 
    total_time = round(total_time, 1)
    print('Simulation time: ' + str(total_time) + 's')
    
    #### Fit
    ###### Fit
    def von_misses(x,mu,k):
        return (exp( k * cos(x-mu))) / (2*pi*scipy.special.i0(k)) 

    def bi_von_misses(x,mu1,k1,mu2,k2):
        return von_misses(x,mu1,k1) + von_misses(x,mu2,k2)

    ##
    y=np.reshape(rE, (N)) 
    X=np.reshape(np.linspace(-pi, pi, N), N)

    ### Fit
    df_n_p=pd.DataFrame()
    df_n_p['rE'] = rE.reshape(512)
    peaks_list=[]
    for n_w_s in range(1, 100):
        r = df_n_p['rE'].rolling(window=n_w_s).mean()
        number_of_bumps = len(scipy.signal.find_peaks(r, 2)[0]) 
        peaks_list.append(number_of_bumps)
    #
    if number_of_bumps == 0:
        if peaks_list==[0 for i in range(len(peaks_list))]:
            number_of_bumps = 0
        else:
            peaks_list[:] = (value for value in peaks_list if value != 0)
            number_of_bumps=most_frequent(peaks_list)
    #
    number_of_bumps=most_frequent(peaks_list)
    #print(number_of_bumps)
    number_of_bumps = 2
    ### Fit
    ### Fit
    if number_of_bumps ==2:
        param, covs = curve_fit(bi_von_misses, X, y, p0=[separation, 75, -separation, 75])
        ans = (exp( param[1] * cos(X-param[0]))) / (2*pi*scipy.special.i0(param[1])) + (exp( param[3] * cos(X-param[2]))) / (2*pi*scipy.special.i0(param[3])) 
        estimated_angles=[]
        for p in [param[0], param[2]]:
            estim_ang = np.degrees(p)
            if estim_ang<0:
                estim_ang = 360+estim_ang
            estimated_angles.append(estim_ang)
        
        #          
        estimated_angle_1=estimated_angles[0]
        estimated_angle_2=estimated_angles[1]
        #print(estimated_angle_1, estimated_angle_2)
        estimated_angles = [estimated_angle_1, estimated_angle_2]
        #estimated_angles.sort()
        #
        
        
        ### wich one is the target and which the distractor?????
        
        
        min_bias = min(  abs(np.degrees( origin + pi/separation) - estimated_angle_1 ), abs( np.degrees( origin - pi/separation) - estimated_angle_1  ) )
        if min_bias == abs(np.degrees( origin + pi/separation) - estimated_angle_1 ):
            dist_ang = estimated_angle_1
            targ_ang = estimated_angle_2
            #bias_b1 = np.degrees( origin + pi/separation) -  estimated_angle_1 
            #bias_b2 = np.degrees( origin - pi/separation) -  estimated_angle_2 
            ####
            #bias_dist = Interference_effects(  [np.degrees( origin + pi/separation)],  [dist_ang],  [np.degrees( origin - pi/separation)])[0]
            #bias_target = Interference_effects(  [np.degrees( origin - pi/separation)],  [targ_ang],  [np.degrees( origin + pi/separation)])[0]
            #
            bias_dist = Interference_effects(  [decode_rE(target)],  [dist_ang],  [decode_rE(distractor)])[0]
            bias_target = Interference_effects(  [decode_rE(distractor)],  [targ_ang],  [decode_rE(target)])[0]
            

        else:
            targ_ang = estimated_angle_1
            dist_ang = estimated_angle_2
            #bias_b1 = np.degrees( origin - pi/separation) -  estimated_angle_1 
            #bias_b2 = np.degrees( origin + pi/separation) -  estimated_angle_2 
            ####
            #decode_rE(target)
            #bias_target = Interference_effects(  [np.degrees( origin - pi/separation)],  [targ_ang],  [np.degrees( origin + pi/separation)])[0]
            #bias_dist = Interference_effects(  [np.degrees( origin + pi/separation)],  [dist_ang],  [np.degrees( origin - pi/separation)])[0]
            ##
            bias_target = Interference_effects(  [decode_rE(distractor)],  [targ_ang],  [decode_rE(target)])[0]
            bias_dist = Interference_effects(  [decode_rE(target)],  [dist_ang],  [decode_rE(distractor)])[0]
            
            ##
        
        ###
        #print('target',round(targ_ang,2), round(decode_rE(distractor), 2), round(bias_target,2))
        #print('distractor', round(dist_ang,2), round(decode_rE(target),2), round(bias_dist,2))
        final_bias = [bias_target, bias_dist]
        skip_r_sq=False
        success=True
        #print(np.degrees( origin - pi/separation), decode_rE(target))
        #print(np.degrees( origin + pi/separation), decode_rE(distractor))
        #print(targ_ang, dist_ang)


    elif number_of_bumps ==1:
        param, covs = curve_fit(von_misses, X, y)
        ans = (exp( param[1] * cos(X-param[0]))) / (2*pi*scipy.special.i0(param[1])) 
        estimated_angle_1=np.degrees(param[0]+pi)
        estimated_angle_2=np.degrees(param[0]+pi)
        estimated_angle=np.degrees(param[0]+pi)  
        
        min_bias = min(  abs(estimated_angle - np.degrees( origin + pi/separation)), 
                       abs(estimated_angle - np.degrees( origin - pi/separation))  )
        if min_bias == abs(estimated_angle - np.degrees( origin + pi/separation)):
            bias_b1 = estimated_angle - np.degrees( origin + pi/separation)
            bias_b2 = estimated_angle - np.degrees( origin - pi/separation)
        else:
            bias_b1 = estimated_angle - np.degrees( origin - pi/separation)
            bias_b2 = estimated_angle - np.degrees( origin + pi/separation)
        ##
        #bias_b1 = estimated_angle - np.degrees( origin - pi/separation)
        #bias_b2 = np.degrees(origin + pi/separation) - estimated_angle  ## bias (positive means attraction)
        final_bias = [bias_b1, bias_b2]  
        skip_r_sq=False
        success=True

    else:
        print('Error simultaion')
        final_bias=[999, 999]
        plot_fit=False
        skip_r_sq=True
        r_squared=0
        success=False ## to eliminate wrong simulations easily at the end

    #error_fit (r_squared)
    if skip_r_sq==False:
        residuals = y - ans
        ss_res = np.sum(residuals**2)
        ss_tot = np.sum((y-numpy.mean(y))**2)
        r_squared = 1 - (ss_res / ss_tot)

    #plot fit
    if plot_fit==True:
        plt.figure()
        plt.plot(X, y, 'o', color ='red', label ="data") 
        plt.plot(X, ans, '--', color ='blue', label ="fit") 
        plt.legend() 
        plt.show(block=False) 
    
    ### Output
    #return RE,  RI, p_u, p_x
    #return interference, targ_dist_delay 
    max_re = max(rE)[0]
    ### interfernce max
    dec_far = np.linspace(180,0,int(N/2))[np.where(y[int(N/2):]==max(y[int(N/2):]))[0][0]]
    #dec_close = np.linspace(180,0,int(N/2))[np.where(y1[int(N/2):]==max(y1[int(N/2):]))[0][0]]
    #int_close = dec_close - np.degrees( pi - pi/4)
    int_far = dec_far - np.degrees( pi - pi/4)
    
    return int_far, max_re, bias_dist, bias_target,  number_of_bumps, targ_ang, dist_ang, X, y #rE[p_targ][0], I0E

# %%
interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y  = simulation_2_7(totalTime=9600,
                                                                                                          targ_onset = 3950,
                                                                                                          dist_onset=200, 
                                                                                                          presentation_period=250,
                                                                                                          separation=4, 
                                                                                                          inhib_curr=True, 
                                                                                                          time_ex_input=0, 
                                                                                                          sigE=0.7, 
                                                                                                          plot_connectivity=False, 
                                                                                                          plot_dyniamic=False, 
                                                                                                          plot_heatmap=True, 
                                                                                                          plot_fit=True )
print(interference, bias_target, bias_dist)
# Out:
# Simulation time: 75.0s
# -1.588235294117652 -0.24 -14.44

# %%
def simulation_o2(totalTime, targ_onset, dist_onset, presentation_period, separation, inhib_curr,
               time_ex_input=10, tauE=60, tauI=10, tauf=7000, taud=80, I0E=1.3, I0I=0.4, U=0.4,
               GEE=0.0165, GEI=0.015, GIE=0.012 , GII=0.007, sigE=0.06, sigI=0.04,
               kappa_E=100, kappa_I=1.5, k_inhib=0.07, kappa_stim=20,
               N=512, plot_connectivity=True, plot_dyniamic=True, plot_heatmap=True, plot_fit=True ):
    
    ###### temporal and spatial settings
    st_sim =time.time()
    dt=2;
    nsteps=int(floor(totalTime/dt));
    origin = pi;
    targ_offset = targ_onset + presentation_period;
    targon = floor(targ_onset/dt);
    targoff = floor(targ_offset/dt);
    
    dist_offset = dist_onset  + presentation_period;
    diston = floor(dist_onset/dt);
    distoff = floor(dist_offset/dt);
    stim_sep = pi/separation; #(13 attract, 9 solo 1, 5 repulsion, 2 nada)
    
    targ_dist_delay = dist_onset - targ_offset
    
    if inhib_curr == True:
        I0E_open = I0E
        I0E=I0E_open-0.9
    
    ###### Connectivities
    v_E=np.zeros((N));
    v_I=np.zeros((N));
    WE=np.zeros((N,N));
    WI=np.zeros((N,N));
    theta = [float(range(0,N)[i])/N*2*pi for i in range(0,N)];
    for i in range(0, N):
        v_E_new=[e**(kappa_E*cos(theta[f]))/(2*pi*scipy.special.i0(kappa_E)) for f in range(0, len(theta))]    
        v_I_new=[e**(kappa_I*cos(theta[f]))/(2*pi*scipy.special.i0(kappa_I)) + k_inhib for f in range(0, len(theta))] #0.18
        ###    
        vE_NEW=np.roll(v_E_new,i)
        vI_NEW=np.roll(v_I_new,i) #to roll
        ###    
        WE[:,i]=vE_NEW
        WI[:,i]=vI_NEW
    
    #
        # Plot of the connectivity profile
    if plot_connectivity ==True:
        plt.figure()
        plt.plot(WE[250, :], label='E')
        plt.plot(WI[250, :], label = 'I')
        plt.ylim(0,6)
        plt.gca().spines['right'].set_visible(False) #no right axis
        plt.gca().spines['top'].set_visible(False) #no  top axis
        plt.gca().get_xaxis().tick_bottom()
        plt.gca().get_yaxis().tick_left()
        plt.title('Connectivity WE & WI')
        plt.show(block=False)
        plt.figure()
        plt.plot(WE[250, :] - WI[250, :] , label='E-I')
        #plt.plot(WI[250, :], label = 'I')
        #plt.ylim(0,6)
        plt.gca().spines['right'].set_visible(False) #no right axis
        plt.gca().spines['top'].set_visible(False) #no  top axis
        plt.gca().get_xaxis().tick_bottom()
        plt.gca().get_yaxis().tick_left()
        plt.title('Effective onnectivity')
        plt.show(block=False)
    #topography_pattern  =  WE[250, :] + -1*(WI[250, :]) ##plot the topography of the connectivities
    #plt.plot(topography_pattern, 'k')
    #plt.show(block=False)
    
    ###### Stimuli
    target=np.zeros((N))
    distractor=np.zeros((N))
    for i in range(0, N):
        target[i]=e**(kappa_stim*cos(theta[i] + origin - stim_sep)) / (2*pi*scipy.special.i0(kappa_stim)) 
        distractor[i]=e**(kappa_stim*cos(theta[i] + origin + stim_sep)) / (2*pi*scipy.special.i0(kappa_stim)) 


    target = target+ np.random.normal(0, 0.01, N)
    target=reshape(target, (N,1))
    distractor = distractor+ np.random.normal(0, 0.01, N)
    distractor=reshape(distractor, (N,1)) 
    
    #plt.plot(target) ##plot the target and distractor
    #plt.plot(distractor)
    #plt.show(block=False)
    
    ###### Model   
    rE=np.zeros((N,1));
    rI=np.zeros((N,1)); 
    u = np.ones((N,1))*U
    x = np.ones((N,1))
    RE=np.zeros((N,nsteps));
    RI=np.zeros((N,nsteps));
    p_u=np.ones((N,nsteps));
    p_x=np.ones((N,nsteps));
    
    f = lambda x : x*x*(x>0)*(x<1) + reshape(array([cmath.sqrt(4*x[i]-3) for i in range(0, len(x))]).real, (N,1)) * (x>=1)
    
    ### diferential equations
    for i in range(0, nsteps):
        noiseE = sigE*random.randn(N,1);
        noiseI = sigI*random.randn(N,1);

        #differential equations for connectivity
        IE= GEE*dot(WE, (rE*u*x)) - GIE*dot(WI,rI) + I0E*ones((N,1)); 
        II= GEI*dot(WE,rE) +  (I0I-GII*mean(rI))*ones((N,1));

        if i>targon and i<targoff:
            IE=IE+target;
            II=II+target;

        if i>diston and i<distoff:
            IE=IE+distractor;
            II=II+distractor;
        
        if inhib_curr == True:
            if i > distoff+time_ex_input:
                I0E=I0E_open
        
        ###
        #rates of exit and inhib   
        rE = rE + (f(IE) - rE + noiseE)*dt/tauE;
        rI = rI + (f(II) - rI + noiseI)*dt/tauI;
        ### formulas for synaptic plasticity: paper mongillo 2008
        u = u + ((U - u) / tauf + U*(1-u)*rE/1000)*dt;
        x = x + ((1 - x)/taud - u*x*rE/1000)*dt;
        
        rEr=np.reshape(rE, N)
        rIr=np.reshape(rI, N)
        ur=np.reshape(u, N)
        xr=np.reshape(x, N)
        #append
        RE[:,i] = rEr;
        RI[:,i] = rIr;
        p_u[:,i] = ur;
        p_x[:,i] = xr;
    
    
    #### Interference
    interference = Interference_effects( [decode_rE(target)], [decode_rE(rE)], [decode_rE(distractor)])[0]
    
    if plot_dyniamic==True:
        #### plot dynamics
        fig = plt.figure()
        fig.tight_layout()
        fig.set_size_inches(13, 4)
        fig.add_subplot(131)
        p_targ = int((N * np.degrees(origin + stim_sep))/360)
        plt.title('Synaptic dynamics for target')
        plt.plot(p_u[p_targ, :], 'b', label='prob. release')
        plt.plot(p_x[p_targ, :], 'r', label='pool vesicles')
        plt.xlabel('time (ms)')
        plt.legend()
        fig.add_subplot(132)
        p_dist= int((N * np.degrees(origin - stim_sep))/360)
        plt.title('Synaptic dynamics for distractor')
        plt.plot(p_u[p_dist, :], 'b', label='prob.y release')
        plt.plot(p_x[p_dist, :], 'r', label='pool vesicles')
        plt.xlabel('time (ms)')
        plt.legend()
        fig.add_subplot(133)
        plt.title('Rate dynamics')
        plt.plot(RE[p_targ, :], 'b', label='target')
        plt.plot(RE[p_dist, :], 'r', label='distractor')
        plt.xlabel('time (ms)')
        plt.ylabel('rate (Hz)')
        plt.legend()
        plt.show(block=False)

    if plot_heatmap==True:
        #### plot heatmap
        p_dist= int((N * np.degrees(origin - stim_sep))/360)
        RE_sorted=flipud(RE)
        plt.figure(figsize=(9,6))
        sns.heatmap(RE_sorted, cmap='viridis')
        plt.title('BUMP activity')
        plt.ylabel('Angle')
        plt.xlabel('time')
        plt.plot([targon, nsteps], [p_dist, p_dist], '--b',) ## flipped, so it is p_target 
        plt.plot([diston, nsteps], [p_targ, p_targ], '--r',) ## flipped, so it is p_target 
        plt.yticks([])
        plt.xticks([])
        plt.yticks([N/8, 3*N/8, 5*N/8, 7*N/8 ] ,['45','135','225', '315'])
        plt.plot([targ_onset/2, targ_onset/2,], [0+20, N-20], 'k-', label='onset')
        plt.plot([targ_offset/2, targ_offset/2,], [0+20, N-20], 'k--', label='offset')
        plt.plot([dist_onset/2, dist_onset/2,], [0+20, N-20], 'k-')
        plt.plot([dist_offset/2, dist_offset/2,], [0+20, N-20], 'k--')
        plt.legend()
        plt.show(block=False)
    
    
    ## print time consumed
    end_sim =time.time()
    total_time= end_sim - st_sim 
    total_time = round(total_time, 1)
    print('Simulation time: ' + str(total_time) + 's')
    
    #### Fit
    ###### Fit
    def von_misses(x,mu,k):
        return (exp( k * cos(x-mu))) / (2*pi*scipy.special.i0(k)) 

    def bi_von_misses(x,mu1,k1,mu2,k2):
        return von_misses(x,mu1,k1) + von_misses(x,mu2,k2)

    ##
    y=np.reshape(rE, (N)) 
    X=np.reshape(np.linspace(-pi, pi, N), N)

    ### Fit
    df_n_p=pd.DataFrame()
    df_n_p['rE'] = rE.reshape(512)
    peaks_list=[]
    for n_w_s in range(1, 100):
        r = df_n_p['rE'].rolling(window=n_w_s).mean()
        number_of_bumps = len(scipy.signal.find_peaks(r, 2)[0]) 
        peaks_list.append(number_of_bumps)
    #
    if number_of_bumps == 0:
        if peaks_list==[0 for i in range(len(peaks_list))]:
            number_of_bumps = 0
        else:
            peaks_list[:] = (value for value in peaks_list if value != 0)
            number_of_bumps=most_frequent(peaks_list)
    #
    number_of_bumps=most_frequent(peaks_list)
    #print(number_of_bumps)
    number_of_bumps = 2


    ### Fit    
    if number_of_bumps ==2:
        param, covs = curve_fit(bi_von_misses, X, y, p0=[separation, 75, -separation, 75])
        ans = (exp( param[1] * cos(X-param[0]))) / (2*pi*scipy.special.i0(param[1])) + (exp( param[3] * cos(X-param[2]))) / (2*pi*scipy.special.i0(param[3])) 
        estimated_angles=[]
        for p in [param[0], param[2]]:
            estim_ang = np.degrees(p)
            if estim_ang<0:
                estim_ang = 360+estim_ang
            estimated_angles.append(estim_ang)
        
        #          
        estimated_angle_1=estimated_angles[0]
        estimated_angle_2=estimated_angles[1]
        #print(estimated_angle_1, estimated_angle_2)
        estimated_angles = [estimated_angle_1, estimated_angle_2]
        #estimated_angles.sort()
        #
        
        
        ### wich one is the target and which the distractor?????
        
        
        min_bias = min(  abs(np.degrees( origin + pi/separation) - estimated_angle_1 ), abs( np.degrees( origin - pi/separation) - estimated_angle_1  ) )
        if min_bias == abs(np.degrees( origin + pi/separation) - estimated_angle_1 ):
            dist_ang = estimated_angle_1
            targ_ang = estimated_angle_2
            #bias_b1 = np.degrees( origin + pi/separation) -  estimated_angle_1 
            #bias_b2 = np.degrees( origin - pi/separation) -  estimated_angle_2 
            ####
            #bias_dist = Interference_effects(  [np.degrees( origin + pi/separation)],  [dist_ang],  [np.degrees( origin - pi/separation)])[0]
            #bias_target = Interference_effects(  [np.degrees( origin - pi/separation)],  [targ_ang],  [np.degrees( origin + pi/separation)])[0]
            #
            bias_dist = Interference_effects(  [decode_rE(target)],  [dist_ang],  [decode_rE(distractor)])[0]
            bias_target = Interference_effects(  [decode_rE(distractor)],  [targ_ang],  [decode_rE(target)])[0]
            

        else:
            targ_ang = estimated_angle_1
            dist_ang = estimated_angle_2
            #bias_b1 = np.degrees( origin - pi/separation) -  estimated_angle_1 
            #bias_b2 = np.degrees( origin + pi/separation) -  estimated_angle_2 
            ####
            #decode_rE(target)
            #bias_target = Interference_effects(  [np.degrees( origin - pi/separation)],  [targ_ang],  [np.degrees( origin + pi/separation)])[0]
            #bias_dist = Interference_effects(  [np.degrees( origin + pi/separation)],  [dist_ang],  [np.degrees( origin - pi/separation)])[0]
            ##
            bias_target = Interference_effects(  [decode_rE(distractor)],  [targ_ang],  [decode_rE(target)])[0]
            bias_dist = Interference_effects(  [decode_rE(target)],  [dist_ang],  [decode_rE(distractor)])[0]
            
            ##
        
        ###
        #print('target',round(targ_ang,2), round(decode_rE(distractor), 2), round(bias_target,2))
        #print('distractor', round(dist_ang,2), round(decode_rE(target),2), round(bias_dist,2))
        final_bias = [bias_target, bias_dist]
        skip_r_sq=False
        success=True
        #print(np.degrees( origin - pi/separation), decode_rE(target))
        #print(np.degrees( origin + pi/separation), decode_rE(distractor))
        #print(targ_ang, dist_ang)
    
    ###
    elif number_of_bumps ==1:
        param, covs = curve_fit(von_misses, X, y)
        ans = (exp( param[1] * cos(X-param[0]))) / (2*pi*scipy.special.i0(param[1])) 
        estimated_angle=np.degrees(param[0]+pi)  
        
        min_bias = min(  abs(estimated_angle - np.degrees( origin + pi/separation)), 
                       abs(estimated_angle - np.degrees( origin - pi/separation))  )
        if min_bias == abs(estimated_angle - np.degrees( origin + pi/separation)):
            bias_b1 = estimated_angle - np.degrees( origin + pi/separation)
            bias_b2 = estimated_angle - np.degrees( origin - pi/separation)
        else:
            bias_b1 = estimated_angle - np.degrees( origin - pi/separation)
            bias_b2 = estimated_angle - np.degrees( origin + pi/separation)
        ##
        #bias_b1 = estimated_angle - np.degrees( origin - pi/separation)
        #bias_b2 = np.degrees(origin + pi/separation) - estimated_angle  ## bias (positive means attraction)
        final_bias = [bias_b1, bias_b2]  
        skip_r_sq=False
        success=True

    else:
        print('Error simultaion')
        final_bias=[999, 999]
        plot_fit=False
        skip_r_sq=True
        r_squared=0
        success=False ## to eliminate wrong simulations easily at the end

    #error_fit (r_squared)
    if skip_r_sq==False:
        residuals = y - ans
        ss_res = np.sum(residuals**2)
        ss_tot = np.sum((y-numpy.mean(y))**2)
        r_squared = 1 - (ss_res / ss_tot)

    #plot fit
    if plot_fit==True:
        plt.figure()
        plt.plot(X, y, 'o', color ='red', label ="data") 
        plt.plot(X, ans, '--', color ='blue', label ="fit") 
        plt.legend() 
        plt.show(block=False) 
    
    ### Output
    #return RE,  RI, p_u, p_x
    #return interference, targ_dist_delay 
    max_re = max(rE)[0]
    ### interfernce max
    dec_far = np.linspace(180,0,int(N/2))[np.where(y[int(N/2):]==max(y[int(N/2):]))[0][0]]
    #dec_close = np.linspace(180,0,int(N/2))[np.where(y1[int(N/2):]==max(y1[int(N/2):]))[0][0]]
    #int_close = dec_close - np.degrees( pi - pi/4)
    int_far = dec_far - np.degrees( pi - pi/4)
    
    return int_far, max_re, bias_dist, bias_target,  number_of_bumps, targ_ang, dist_ang, X, y #rE[p_targ][0], I0E

# %%
interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y  =  simulation_o2(totalTime=6650,
                                                                                                          targ_onset = 550, 
                                                                                                          dist_onset=200, 
                                                                                                          presentation_period=250, 
                                                                                                          separation=4, 
                                                                                                          inhib_curr=True, 
                                                                                                          time_ex_input=0, 
                                                                                                          sigE=0.7 )


print(interference, bias_target, bias_dist)
# Out:
# Simulation time: 55.7s
# -0.17647058823530415 -0.79 -12.01

# %%
biases_o1_d02 = []

for sim in range(300):
    interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y1  = simulation(totalTime=6450, 
                                                                                                          targ_onset = 200, 
                                                                                                          dist_onset=450+100 , 
                                                                                                          presentation_period=250, 
                                                                                                          separation=4, sigE=0.7,
                                                                                                          plot_connectivity=False,
                                                                                                          plot_dyniamic=False,
                                                                                                          plot_heatmap=False, 
                                                                                                          plot_fit=False,
                                                                                                          GEE=0.016)

    ##

    biases_o1_d02.append([interference, bias_target, bias_dist])
# Out:
# Simulation time: 27.2s
# Simulation time: 28.7s
# Simulation time: 31.9s
# Simulation time: 29.1s
# Simulation time: 27.1s
# Simulation time: 27.9s
# Simulation time: 29.1s
# Simulation time: 31.6s
# Simulation time: 29.4s
# Simulation time: 26.3s
# Simulation time: 27.9s
# Simulation time: 29.9s
# Simulation time: 31.7s
# Simulation time: 28.0s
# Simulation time: 25.9s
# Simulation time: 26.5s
# Simulation time: 29.2s
# Simulation time: 31.2s
# Simulation time: 30.1s
# Simulation time: 27.1s
# Simulation time: 26.7s
# Simulation time: 27.5s
# Simulation time: 31.5s
# Simulation time: 29.4s
# Simulation time: 27.0s
# Simulation time: 25.4s
# Simulation time: 28.3s
# Simulation time: 29.9s
# Simulation time: 30.0s
# Simulation time: 27.0s
# Simulation time: 25.5s
# Simulation time: 27.8s
# Simulation time: 29.3s
# Simulation time: 28.8s
# Simulation time: 26.1s
# Simulation time: 24.6s
# Simulation time: 24.9s
# Simulation time: 25.4s
# Simulation time: 29.1s
# Simulation time: 26.8s
# Simulation time: 25.6s
# Simulation time: 24.5s
# Simulation time: 26.9s
# Simulation time: 26.6s
# Simulation time: 25.0s
# Simulation time: 24.7s
# Simulation time: 25.3s
# Simulation time: 25.8s
# Simulation time: 25.3s
# Simulation time: 24.9s
# Simulation time: 26.8s
# Simulation time: 25.7s
# Simulation time: 24.6s
# Simulation time: 25.4s
# Simulation time: 26.5s
# Simulation time: 25.0s
# Simulation time: 24.6s
# Simulation time: 25.1s
# Simulation time: 26.2s
# Simulation time: 25.0s
# Simulation time: 24.7s
# Simulation time: 25.0s
# Simulation time: 27.1s
# Simulation time: 25.9s
# Simulation time: 24.9s
# Simulation time: 26.0s
# Simulation time: 27.1s
# Simulation time: 25.0s
# Simulation time: 24.4s
# Simulation time: 25.4s
# Simulation time: 25.2s
# Simulation time: 24.7s
# Simulation time: 24.4s
# Simulation time: 24.8s
# Simulation time: 26.8s
# Simulation time: 24.8s
# Simulation time: 25.3s
# Simulation time: 27.8s
# Simulation time: 24.6s
# Simulation time: 24.7s
# Simulation time: 24.5s
# Simulation time: 24.7s
# Simulation time: 24.8s
# Simulation time: 24.6s
# Simulation time: 24.9s
# Simulation time: 24.8s
# Simulation time: 25.4s
# Simulation time: 27.2s
# Simulation time: 25.5s
# Simulation time: 26.1s
# Simulation time: 25.1s
# Simulation time: 25.2s
# Simulation time: 24.6s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 24.8s
# Simulation time: 24.6s
# Simulation time: 24.5s
# Simulation time: 26.1s
# Simulation time: 25.8s
# Simulation time: 26.5s
# Simulation time: 24.8s
# Simulation time: 24.7s
# Simulation time: 24.7s
# Simulation time: 24.9s
# Simulation time: 24.9s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.1s
# Simulation time: 24.4s
# Simulation time: 27.0s
# Simulation time: 25.0s
# Simulation time: 26.2s
# Simulation time: 25.0s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 24.5s
# Simulation time: 25.3s
# Simulation time: 24.8s
# Simulation time: 24.9s
# Simulation time: 25.2s
# Simulation time: 26.4s
# Simulation time: 26.6s
# Simulation time: 30.2s
# Simulation time: 29.7s
# Simulation time: 30.4s
# Simulation time: 25.8s
# Simulation time: 24.6s
# Simulation time: 24.4s
# Simulation time: 24.6s
# Simulation time: 24.7s
# Simulation time: 25.1s
# Simulation time: 25.2s
# Simulation time: 26.1s
# Simulation time: 26.9s
# Simulation time: 24.6s
# Simulation time: 24.7s
# Simulation time: 24.9s
# Simulation time: 24.8s
# Simulation time: 25.1s
# Simulation time: 24.1s
# Simulation time: 24.6s
# Simulation time: 25.0s
# Simulation time: 24.5s
# Simulation time: 24.8s
# Simulation time: 26.1s
# Simulation time: 27.1s
# Simulation time: 24.9s
# Simulation time: 25.2s
# Simulation time: 24.5s
# Simulation time: 24.3s
# Simulation time: 24.3s
# Simulation time: 24.6s
# Simulation time: 24.6s
# Simulation time: 24.8s
# Simulation time: 24.7s
# Simulation time: 25.1s
# Simulation time: 29.9s
# Simulation time: 28.0s
# Simulation time: 25.1s
# Simulation time: 24.9s
# Simulation time: 25.6s
# Simulation time: 25.1s
# Simulation time: 24.7s
# Simulation time: 24.1s
# Simulation time: 24.6s
# Simulation time: 24.4s
# Simulation time: 24.4s
# Simulation time: 25.0s
# Simulation time: 24.8s
# Simulation time: 27.2s
# Simulation time: 24.7s
# Simulation time: 24.4s
# Simulation time: 24.2s
# Simulation time: 24.6s
# Simulation time: 24.6s
# Simulation time: 24.6s
# Simulation time: 24.8s
# Simulation time: 24.5s
# Simulation time: 25.0s
# Simulation time: 24.5s
# Simulation time: 24.7s
# Simulation time: 27.9s
# Simulation time: 26.0s
# Simulation time: 24.6s
# Simulation time: 24.4s
# Simulation time: 24.8s
# Simulation time: 24.7s
# Simulation time: 24.8s
# Simulation time: 24.5s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.7s
# Simulation time: 26.3s
# Simulation time: 26.5s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 24.6s
# Simulation time: 24.5s
# Simulation time: 24.4s
# Simulation time: 25.1s
# Simulation time: 24.5s
# Simulation time: 24.8s
# Simulation time: 25.4s
# Simulation time: 26.2s
# Simulation time: 24.8s
# Simulation time: 25.2s
# Simulation time: 24.7s
# Simulation time: 24.6s
# Simulation time: 24.9s
# Simulation time: 24.7s
# Simulation time: 25.6s
# Simulation time: 24.7s
# Simulation time: 24.6s
# Simulation time: 26.5s
# Simulation time: 25.6s
# Simulation time: 25.6s
# Simulation time: 25.6s
# Simulation time: 24.8s
# Simulation time: 24.3s
# Simulation time: 24.6s
# Simulation time: 24.3s
# Simulation time: 24.3s
# Simulation time: 24.6s
# Simulation time: 25.8s
# Simulation time: 24.6s
# Simulation time: 28.3s
# Simulation time: 25.9s
# Simulation time: 25.2s
# Simulation time: 26.7s
# Simulation time: 25.2s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 25.0s
# Simulation time: 25.4s
# Simulation time: 24.8s
# Simulation time: 24.8s
# Simulation time: 25.0s
# Simulation time: 26.2s
# Simulation time: 25.2s
# Simulation time: 25.2s
# Simulation time: 26.4s
# Simulation time: 25.0s
# Simulation time: 25.4s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.2s
# Simulation time: 25.4s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 26.1s
# Simulation time: 25.1s
# Simulation time: 24.8s
# Simulation time: 26.5s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.7s
# Simulation time: 25.3s
# Simulation time: 25.6s
# Simulation time: 26.2s
# Simulation time: 26.4s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 25.3s
# Simulation time: 25.6s
# Simulation time: 25.2s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 24.9s
# Simulation time: 25.7s
# Simulation time: 25.4s
# Simulation time: 25.8s
# Simulation time: 25.7s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 25.5s
# Simulation time: 26.6s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.0s
# Simulation time: 24.7s
# Simulation time: 24.8s
# Simulation time: 25.1s
# Simulation time: 26.0s
# Simulation time: 26.2s
# Simulation time: 25.1s
# Simulation time: 25.0s
# Simulation time: 24.9s
# Simulation time: 26.9s
# Simulation time: 25.2s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 25.3s

# %%
biases_o1_d02
# Out:
# [[-4.411764705882348, -5.74, -3.94],
#  [-5.117647058823536, -5.29, -2.77],
#  [-8.64705882352942, -6.45, -3.09],
#  [-5.823529411764696, -7.25, -2.06],
#  [-6.529411764705884, -7.64, -2.03],
#  [-8.64705882352942, -7.52, -2.44],
#  [-3.0, -5.25, -5.13],
#  [-5.823529411764696, -5.33, -2.78],
#  [-4.411764705882348, -6.14, -3.01],
#  [-4.411764705882348, -7.27, -3.01],
#  [-3.705882352941188, -4.37, -4.33],
#  [-4.411764705882348, -5.12, -3.91],
#  [-3.705882352941188, -5.71, -4.51],
#  [-8.64705882352942, -6.45, -2.97],
#  [-6.529411764705884, -6.66, -2.88],
#  [-10.764705882352942, -8.36, -2.2],
#  [-5.117647058823536, -5.15, -3.37],
#  [-4.411764705882348, -5.76, -3.09],
#  [-7.235294117647072, -5.76, -3.03],
#  [-3.0, -5.98, -3.08],
#  [-7.235294117647072, -6.99, -1.73],
#  [-4.411764705882348, -5.94, -3.61],
#  [-3.705882352941188, -6.41, -2.71],
#  [-10.058823529411768, -8.35, -3.29],
#  [-9.352941176470594, -5.44, -3.42],
#  [-7.235294117647072, -6.02, -3.69],
#  [-6.529411764705884, -6.99, -2.92],
#  [-7.235294117647072, -6.87, -2.48],
#  [-7.235294117647072, -7.12, -3.48],
#  [-5.117647058823536, -7.36, -3.57],
#  [-7.235294117647072, -6.09, -3.69],
#  [-5.117647058823536, -6.26, -3.74],
#  [-6.529411764705884, -6.25, -2.5],
#  [-7.941176470588232, -6.87, -2.65],
#  [-7.235294117647072, -6.86, -2.75],
#  [-8.64705882352942, -5.87, -4.47],
#  [-6.529411764705884, -5.73, -4.33],
#  [-9.352941176470594, -6.69, -2.58],
#  [-5.117647058823536, -6.12, -2.82],
#  [-3.705882352941188, -6.12, -3.92],
#  [-5.117647058823536, -5.42, -3.54],
#  [-3.0, -5.52, -4.37],
#  [-6.529411764705884, -4.78, -4.44],
#  [-2.2941176470588402, -3.96, -4.66],
#  [-7.235294117647072, -6.82, -2.21],
#  [-7.941176470588232, -6.46, -2.39],
#  [-6.529411764705884, -7.91, -2.09],
#  [-8.64705882352942, -7.75, -2.43],
#  [-3.0, -5.79, -2.74],
#  [-3.705882352941188, -6.53, -2.64],
#  [-6.529411764705884, -6.71, -3.56],
#  [-4.411764705882348, -5.17, -3.74],
#  [-3.0, -4.93, -3.75],
#  [-9.352941176470594, -6.4, -3.08],
#  [-7.235294117647072, -6.83, -2.41],
#  [-9.352941176470594, -6.05, -3.36],
#  [-5.823529411764696, -5.97, -3.08],
#  [-5.823529411764696, -6.31, -3.17],
#  [-4.411764705882348, -6.61, -3.04],
#  [-5.117647058823536, -5.05, -3.31],
#  [-4.411764705882348, -6.03, -3.26],
#  [-7.941176470588232, -6.94, -3.86],
#  [-5.823529411764696, -6.19, -2.46],
#  [-7.235294117647072, -6.16, -3.49],
#  [-5.117647058823536, -6.74, -2.7],
#  [-3.705882352941188, -5.02, -3.07],
#  [-7.235294117647072, -5.89, -2.46],
#  [-6.529411764705884, -5.23, -4.8],
#  [-5.823529411764696, -6.76, -2.43],
#  [-4.411764705882348, -7.26, -3.03],
#  [-7.235294117647072, -5.98, -3.72],
#  [-7.941176470588232, -6.21, -3.6],
#  [-4.411764705882348, -5.68, -3.66],
#  [-4.411764705882348, -7.17, -2.49],
#  [-3.0, -5.02, -4.18],
#  [-5.117647058823536, -4.88, -4.01],
#  [-7.941176470588232, -6.87, -2.91],
#  [-3.0, -5.72, -4.66],
#  [-5.823529411764696, -7.53, -3.45],
#  [-5.823529411764696, -4.92, -3.58],
#  [-11.470588235294116, -8.77, -2.8],
#  [-5.823529411764696, -5.98, -3.71],
#  [-8.64705882352942, -6.12, -4.36],
#  [-0.8823529411764639, -6.19, -1.78],
#  [-3.705882352941188, -6.62, -3.5],
#  [-3.705882352941188, -5.47, -3.24],
#  [-3.0, -5.38, -3.88],
#  [-8.64705882352942, -5.87, -3.91],
#  [-7.235294117647072, -5.52, -2.97],
#  [-7.941176470588232, -4.78, -3.97],
#  [-5.117647058823536, -6.8, -2.68],
#  [-6.529411764705884, -5.7, -3.57],
#  [-8.64705882352942, -7.83, -3.62],
#  [-5.823529411764696, -7.24, -3.16],
#  [-5.823529411764696, -5.42, -2.79],
#  [-3.705882352941188, -5.44, -3.37],
#  [-5.117647058823536, -5.83, -3.81],
#  [-5.823529411764696, -6.73, -3.12],
#  [-4.411764705882348, -5.97, -4.16],
#  [-4.411764705882348, -6.43, -5.09],
#  [-3.705882352941188, -5.89, -3.16],
#  [-9.352941176470594, -7.02, -2.81],
#  [-7.235294117647072, -8.59, -2.38],
#  [-5.823529411764696, -6.53, -3.6],
#  [-3.0, -6.34, -4.34],
#  [-8.64705882352942, -6.56, -2.99],
#  [-0.8823529411764639, -4.83, -3.26],
#  [-8.64705882352942, -5.95, -3.87],
#  [-7.941176470588232, -5.82, -2.77],
#  [-7.941176470588232, -5.1, -4.76],
#  [-5.823529411764696, -7.03, -2.88],
#  [-7.235294117647072, -6.93, -2.83],
#  [-3.0, -5.36, -3.88],
#  [-5.823529411764696, -4.88, -3.23],
#  [-7.235294117647072, -5.96, -2.99],
#  [-1.588235294117652, -5.61, -3.79],
#  [-5.117647058823536, -5.56, -2.73],
#  [-7.941176470588232, -5.55, -3.66],
#  [-7.235294117647072, -6.42, -4.06],
#  [-3.705882352941188, -6.4, -4.27],
#  [-10.764705882352942, -7.06, -4.03],
#  [-7.941176470588232, -5.76, -3.53],
#  [-5.117647058823536, -7.1, -2.6],
#  [-6.529411764705884, -7.28, -4.31],
#  [-5.823529411764696, -5.26, -3.76],
#  [-6.529411764705884, -6.85, -2.09],
#  [-7.235294117647072, -7.6, -3.13],
#  [-7.941176470588232, -7.14, -3.66],
#  [-5.117647058823536, -4.74, -3.76],
#  [-3.705882352941188, -5.19, -4.01],
#  [-7.941176470588232, -7.76, -2.81],
#  [-7.941176470588232, -5.8, -3.71],
#  [-6.529411764705884, -4.62, -3.4],
#  [-3.0, -4.76, -3.57],
#  [-4.411764705882348, -6.59, -2.24],
#  [-5.117647058823536, -6.75, -2.62],
#  [-9.352941176470594, -7.06, -3.31],
#  [-7.941176470588232, -7.48, -3.83],
#  [-10.058823529411768, -7.68, -1.82],
#  [-5.823529411764696, -5.77, -3.09],
#  [-5.823529411764696, -6.32, -2.38],
#  [-5.117647058823536, -7.44, -2.03],
#  [-4.411764705882348, -5.67, -3.55],
#  [-1.588235294117652, -5.15, -4.98],
#  [-2.2941176470588402, -4.61, -4.55],
#  [-10.058823529411768, -7.59, -3.31],
#  [-5.823529411764696, -6.85, -3.0],
#  [-4.411764705882348, -5.71, -3.66],
#  [-5.117647058823536, -6.85, -3.37],
#  [-5.117647058823536, -6.13, -4.03],
#  [-7.941176470588232, -5.67, -1.95],
#  [-8.64705882352942, -6.07, -3.11],
#  [-7.235294117647072, -7.56, -1.97],
#  [-7.235294117647072, -7.05, -3.05],
#  [-5.823529411764696, -6.56, -3.11],
#  [-8.64705882352942, -5.88, -4.17],
#  [-8.64705882352942, -7.35, -2.92],
#  [-7.941176470588232, -7.93, -2.78],
#  [-9.352941176470594, -6.64, -4.21],
#  [-5.823529411764696, -6.79, -2.5],
#  [-6.529411764705884, -6.49, -2.66],
#  [-5.823529411764696, -6.13, -3.53],
#  [-5.823529411764696, -6.86, -3.28],
#  [-4.411764705882348, -5.33, -3.47],
#  [-6.529411764705884, -6.11, -3.32],
#  [-4.411764705882348, -6.42, -2.79],
#  [-7.941176470588232, -6.12, -2.57],
#  [-8.64705882352942, -5.44, -4.86],
#  [-7.941176470588232, -5.42, -4.11],
#  [-5.117647058823536, -5.31, -3.29],
#  [-10.058823529411768, -8.14, -2.41],
#  [-7.941176470588232, -5.69, -4.03],
#  [-2.2941176470588402, -4.97, -3.5],
#  [-2.2941176470588402, -6.1, -2.35],
#  [-7.941176470588232, -7.32, -3.25],
#  [-6.529411764705884, -7.28, -2.21],
#  [-6.529411764705884, -6.4, -3.69],
#  [-9.352941176470594, -6.47, -3.08],
#  [-7.941176470588232, -9.06, -2.28],
#  [-4.411764705882348, -5.64, -3.73],
#  [-9.352941176470594, -6.12, -3.42],
#  [-6.529411764705884, -6.35, -2.2],
#  [-5.823529411764696, -4.77, -4.51],
#  [-3.0, -5.43, -3.85],
#  [-4.411764705882348, -5.84, -3.61],
#  [-4.411764705882348, -6.53, -3.39],
#  [-8.64705882352942, -6.54, -3.83],
#  [-6.529411764705884, -5.25, -4.12],
#  [-6.529411764705884, -6.23, -2.3],
#  [-5.117647058823536, -6.88, -2.97],
#  [-3.0, -5.99, -2.96],
#  [-10.764705882352942, -5.84, -3.6],
#  [-7.941176470588232, -7.93, -3.72],
#  [-3.0, -5.11, -2.11],
#  [-4.411764705882348, -5.2, -3.74],
#  [-7.941176470588232, -6.98, -1.78],
#  [-7.235294117647072, -7.47, -1.62],
#  [-7.235294117647072, -5.97, -3.9],
#  [-5.117647058823536, -5.43, -5.03],
#  [-7.941176470588232, -5.95, -2.48],
#  [-0.8823529411764639, -5.94, -3.34],
#  [-5.823529411764696, -5.71, -3.88],
#  [-5.117647058823536, -4.86, -3.98],
#  [-6.529411764705884, -6.15, -3.83],
#  [-7.235294117647072, -6.23, -3.87],
#  [-5.117647058823536, -6.27, -3.03],
#  [-5.823529411764696, -6.58, -2.97],
#  [-7.235294117647072, -6.18, -2.48],
#  [-3.705882352941188, -5.18, -3.21],
#  [-8.64705882352942, -5.69, -4.01],
#  [-5.117647058823536, -6.71, -2.99],
#  [-6.529411764705884, -5.84, -3.4],
#  [-4.411764705882348, -5.97, -3.26],
#  [-10.058823529411768, -6.85, -2.58],
#  [-7.941176470588232, -6.34, -3.79],
#  [-5.823529411764696, -5.42, -3.02],
#  [-6.529411764705884, -7.33, -1.78],
#  [-9.352941176470594, -7.08, -1.33],
#  [-5.823529411764696, -6.53, -4.07],
#  [-5.823529411764696, -6.67, -3.08],
#  [-4.411764705882348, -6.72, -3.04],
#  [-7.941176470588232, -7.48, -2.73],
#  [-7.235294117647072, -6.63, -2.95],
#  [-5.117647058823536, -5.86, -2.31],
#  [-5.823529411764696, -8.38, -2.08],
#  [-7.235294117647072, -7.71, -3.4],
#  [-9.352941176470594, -6.23, -4.09],
#  [-5.823529411764696, -6.3, -2.78],
#  [-7.235294117647072, -6.17, -3.36],
#  [-2.2941176470588402, -4.26, -2.92],
#  [-6.529411764705884, -6.46, -3.2],
#  [-7.941176470588232, -7.26, -2.43],
#  [-7.235294117647072, -6.83, -3.28],
#  [-4.411764705882348, -6.59, -4.16],
#  [-7.235294117647072, -6.34, -2.47],
#  [-7.235294117647072, -6.08, -3.27],
#  [-8.64705882352942, -6.84, -2.79],
#  [-6.529411764705884, -5.58, -2.83],
#  [-6.529411764705884, -6.74, -3.06],
#  [-6.529411764705884, -6.3, -3.72],
#  [-5.823529411764696, -5.96, -3.11],
#  [-5.823529411764696, -7.24, -2.35],
#  [-8.64705882352942, -6.34, -2.92],
#  [-9.352941176470594, -6.31, -3.77],
#  [-7.235294117647072, -6.66, -3.13],
#  [-9.352941176470594, -6.66, -3.3],
#  [-3.0, -6.29, -3.76],
#  [-7.941176470588232, -6.77, -2.6],
#  [-2.2941176470588402, -4.83, -3.91],
#  [-5.117647058823536, -7.41, -3.01],
#  [-2.2941176470588402, -3.81, -4.19],
#  [-4.411764705882348, -5.5, -3.52],
#  [-5.823529411764696, -5.9, -2.95],
#  [-7.941176470588232, -5.63, -4.17],
#  [-7.941176470588232, -5.05, -3.3],
#  [-3.705882352941188, -5.71, -2.17],
#  [-7.941176470588232, -7.82, -1.79],
#  [-8.64705882352942, -7.09, -2.32],
#  [-3.705882352941188, -5.49, -3.31],
#  [-5.117647058823536, -5.95, -3.37],
#  [-9.352941176470594, -7.0, -3.17],
#  [-4.411764705882348, -6.53, -2.13],
#  [-9.352941176470594, -6.19, -3.22],
#  [-6.529411764705884, -7.49, -2.08],
#  [-5.823529411764696, -5.8, -3.48],
#  [-3.0, -5.06, -5.29],
#  [-4.411764705882348, -5.45, -2.29],
#  [-5.117647058823536, -5.28, -3.4],
#  [-9.352941176470594, -6.68, -2.08],
#  [-3.705882352941188, -6.55, -2.73],
#  [-9.352941176470594, -6.39, -3.52],
#  [-5.117647058823536, -5.55, -3.6],
#  [-5.117647058823536, -6.42, -3.25],
#  [-3.705882352941188, -5.16, -4.26],
#  [-5.823529411764696, -7.69, -1.45],
#  [-3.705882352941188, -6.73, -3.55],
#  [-7.941176470588232, -7.9, -2.71],
#  [-8.64705882352942, -5.66, -3.47],
#  [-5.823529411764696, -5.31, -3.82],
#  [-5.823529411764696, -7.69, -2.25],
#  [-5.823529411764696, -6.28, -2.78],
#  [-6.529411764705884, -6.74, -4.28],
#  [-3.0, -5.05, -3.35],
#  [-3.705882352941188, -7.36, -3.08],
#  [-5.823529411764696, -6.68, -3.52],
#  [-5.823529411764696, -7.34, -2.99],
#  [-8.64705882352942, -7.73, -2.85],
#  [-2.2941176470588402, -6.06, -3.37],
#  [-5.117647058823536, -4.27, -3.05],
#  [-9.352941176470594, -7.36, -1.65],
#  [-2.2941176470588402, -5.33, -3.74],
#  [-9.352941176470594, -7.38, -3.19],
#  [-9.352941176470594, -6.53, -3.49],
#  [-10.058823529411768, -6.8, -2.47],
#  [-6.529411764705884, -5.41, -3.92],
#  [-7.941176470588232, -6.33, -2.95],
#  [-7.235294117647072, -5.73, -4.5],
#  [-4.411764705882348, -5.52, -4.26],
#  [-5.117647058823536, -5.93, -2.63],
#  [-1.588235294117652, -4.48, -4.28]]

# %%
biases_o1_d7=[]

for sim in range(300):
    interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y  = simulation(totalTime=6450, 
                                                                                                          targ_onset = 200, 
                                                                                                          dist_onset=450+3500 , 
                                                                                                          presentation_period=250, 
                                                                                                          separation=4, sigE=0.7,
                                                                                                          plot_connectivity=False,
                                                                                                          plot_dyniamic=False,
                                                                                                          plot_heatmap=False, 
                                                                                                          plot_fit=False, 
                                                                                                          GEE=0.016)

    biases_o1_d7.append([interference, bias_target, bias_dist])
# Out:
# Simulation time: 25.4s
# Simulation time: 26.8s
# Simulation time: 26.2s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 25.1s
# Simulation time: 25.7s
# Simulation time: 26.4s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 25.3s
# Simulation time: 25.4s
# Simulation time: 25.2s
# Simulation time: 27.0s
# Simulation time: 31.1s
# Simulation time: 34.6s
# Simulation time: 37.8s
# Simulation time: 27.2s
# Simulation time: 26.7s
# Simulation time: 25.3s
# Simulation time: 25.5s
# Simulation time: 25.3s
# Simulation time: 25.8s
# Simulation time: 25.5s
# Simulation time: 26.0s
# Simulation time: 25.4s
# Simulation time: 24.7s
# Simulation time: 24.8s
# Simulation time: 25.1s
# Simulation time: 24.9s
# Simulation time: 26.4s
# Simulation time: 24.7s
# Simulation time: 25.3s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 26.0s
# Simulation time: 26.5s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.5s
# Simulation time: 25.2s
# Simulation time: 25.9s
# Simulation time: 25.6s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 25.6s
# Simulation time: 25.6s
# Simulation time: 26.0s
# Simulation time: 25.2s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 25.9s
# Simulation time: 26.7s
# Simulation time: 25.3s
# Simulation time: 25.2s
# Simulation time: 25.4s
# Simulation time: 25.4s
# Simulation time: 26.1s
# Simulation time: 25.2s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 25.7s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 26.7s
# Simulation time: 25.4s
# Simulation time: 25.7s
# Simulation time: 25.0s
# Simulation time: 26.9s
# Simulation time: 24.6s
# Simulation time: 25.2s
# Simulation time: 25.1s
# Simulation time: 25.6s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.0s
# Simulation time: 26.7s
# Simulation time: 25.3s
# Simulation time: 25.4s
# Simulation time: 25.0s
# Simulation time: 26.4s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.2s
# Simulation time: 24.9s
# Simulation time: 24.8s
# Simulation time: 25.2s
# Simulation time: 25.1s
# Simulation time: 26.6s
# Simulation time: 25.2s
# Simulation time: 25.6s
# Simulation time: 25.2s
# Simulation time: 25.7s
# Simulation time: 25.0s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 25.1s
# Simulation time: 24.9s
# Simulation time: 25.0s
# Simulation time: 25.4s
# Simulation time: 26.0s
# Simulation time: 26.2s
# Simulation time: 25.8s
# Simulation time: 26.1s
# Simulation time: 26.7s
# Simulation time: 25.3s
# Simulation time: 25.6s
# Simulation time: 25.0s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 24.8s
# Simulation time: 25.4s
# Simulation time: 25.9s
# Simulation time: 27.0s
# Simulation time: 25.6s
# Simulation time: 26.1s
# Simulation time: 25.3s
# Simulation time: 25.5s
# Simulation time: 25.0s
# Simulation time: 24.6s
# Simulation time: 24.9s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 24.9s
# Simulation time: 25.2s
# Simulation time: 26.6s
# Simulation time: 24.9s
# Simulation time: 26.9s
# Simulation time: 25.6s
# Simulation time: 25.0s
# Simulation time: 25.3s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 25.4s
# Simulation time: 25.5s
# Simulation time: 26.1s
# Simulation time: 25.4s
# Simulation time: 27.2s
# Simulation time: 26.0s
# Simulation time: 25.8s
# Simulation time: 25.0s
# Simulation time: 25.0s
# Simulation time: 24.9s
# Simulation time: 25.2s
# Simulation time: 25.3s
# Simulation time: 25.8s
# Simulation time: 24.9s
# Simulation time: 25.2s
# Simulation time: 25.3s
# Simulation time: 27.1s
# Simulation time: 25.5s
# Simulation time: 26.2s
# Simulation time: 25.2s
# Simulation time: 25.3s
# Simulation time: 25.4s
# Simulation time: 24.9s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 24.8s
# Simulation time: 24.9s
# Simulation time: 26.3s
# Simulation time: 26.5s
# Simulation time: 26.4s
# Simulation time: 25.7s
# Simulation time: 25.3s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 24.9s
# Simulation time: 25.3s
# Simulation time: 25.2s
# Simulation time: 25.6s
# Simulation time: 26.9s
# Simulation time: 27.0s
# Simulation time: 25.0s
# Simulation time: 25.0s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.6s
# Simulation time: 25.4s
# Simulation time: 25.0s
# Simulation time: 25.2s
# Simulation time: 25.4s
# Simulation time: 25.4s
# Simulation time: 25.7s
# Simulation time: 27.5s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 24.7s
# Simulation time: 24.6s
# Simulation time: 25.1s
# Simulation time: 25.2s
# Simulation time: 25.2s
# Simulation time: 25.2s
# Simulation time: 25.3s
# Simulation time: 27.9s
# Simulation time: 25.7s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.3s
# Simulation time: 25.0s
# Simulation time: 24.7s
# Simulation time: 25.0s
# Simulation time: 24.8s
# Simulation time: 25.8s
# Simulation time: 25.0s
# Simulation time: 27.5s
# Simulation time: 26.6s
# Simulation time: 25.2s
# Simulation time: 25.0s
# Simulation time: 25.4s
# Simulation time: 25.1s
# Simulation time: 24.8s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 25.2s
# Simulation time: 25.3s
# Simulation time: 25.0s
# Simulation time: 25.8s
# Simulation time: 26.9s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.1s
# Simulation time: 25.4s
# Simulation time: 25.4s
# Simulation time: 25.5s
# Simulation time: 25.2s
# Simulation time: 25.6s
# Simulation time: 26.0s
# Simulation time: 25.7s
# Simulation time: 26.4s
# Simulation time: 27.3s
# Simulation time: 25.4s
# Simulation time: 25.6s
# Simulation time: 25.9s
# Simulation time: 25.2s
# Simulation time: 25.1s
# Simulation time: 25.0s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 26.1s
# Simulation time: 26.0s
# Simulation time: 26.0s
# Simulation time: 25.7s
# Simulation time: 24.9s
# Simulation time: 25.0s
# Simulation time: 25.4s
# Simulation time: 25.1s
# Simulation time: 25.5s
# Simulation time: 25.3s
# Simulation time: 26.0s
# Simulation time: 25.6s
# Simulation time: 26.4s
# Simulation time: 24.9s
# Simulation time: 25.6s
# Simulation time: 26.1s
# Simulation time: 25.2s
# Simulation time: 24.9s
# Simulation time: 25.1s
# Simulation time: 25.1s
# Simulation time: 25.3s
# Simulation time: 25.6s
# Simulation time: 25.4s
# Simulation time: 25.4s
# Simulation time: 26.7s
# Simulation time: 25.2s
# Simulation time: 24.9s
# Simulation time: 26.8s
# Simulation time: 25.6s
# Simulation time: 25.4s
# Simulation time: 25.5s
# Simulation time: 25.3s
# Simulation time: 25.2s
# Simulation time: 25.7s
# Simulation time: 25.9s
# Simulation time: 25.6s
# Simulation time: 26.0s
# Simulation time: 24.9s
# Simulation time: 25.3s
# Simulation time: 26.3s
# Simulation time: 25.9s
# Simulation time: 25.0s
# Simulation time: 25.4s
# Simulation time: 25.9s
# Simulation time: 25.3s
# Simulation time: 25.5s
# Simulation time: 25.3s
# Simulation time: 26.1s
# Simulation time: 25.3s
# Simulation time: 25.2s
# Simulation time: 25.5s
# Simulation time: 26.9s
# Simulation time: 25.3s

# %%
biases_o1_d7
# Out:
# [[-1.588235294117652, -2.41, -6.4],
#  [-4.411764705882348, -3.54, -6.15],
#  [-5.117647058823536, -3.23, -7.53],
#  [-3.0, -2.1, -6.51],
#  [-0.17647058823530415, -2.52, -7.05],
#  [-0.17647058823530415, -2.01, -6.59],
#  [-3.0, -2.74, -5.5],
#  [1.2352941176470722, -1.66, -7.39],
#  [-3.0, -2.41, -6.76],
#  [-1.588235294117652, -2.6, -7.01],
#  [-2.2941176470588402, -1.95, -6.46],
#  [-3.0, -2.4, -6.88],
#  [-0.17647058823530415, -2.27, -6.29],
#  [-5.117647058823536, -2.4, -6.93],
#  [-3.0, -2.72, -5.81],
#  [-5.117647058823536, -2.62, -7.18],
#  [-3.705882352941188, -2.48, -7.3],
#  [-3.705882352941188, -2.1, -6.32],
#  [-3.0, -2.12, -7.28],
#  [-0.17647058823530415, -2.21, -6.81],
#  [-0.17647058823530415, -1.92, -5.82],
#  [-1.588235294117652, -2.47, -6.33],
#  [1.2352941176470722, -2.42, -5.66],
#  [-3.0, -2.27, -6.84],
#  [-3.0, -2.22, -6.72],
#  [-2.2941176470588402, -1.65, -7.01],
#  [0.529411764705884, -1.65, -8.5],
#  [-0.17647058823530415, -3.03, -6.77],
#  [-0.8823529411764639, -2.52, -7.14],
#  [-3.0, -2.49, -5.92],
#  [-0.8823529411764639, -2.28, -6.12],
#  [-3.705882352941188, -2.46, -6.54],
#  [-3.0, -2.5, -6.67],
#  [-0.8823529411764639, -3.07, -6.35],
#  [1.941176470588232, -2.76, -6.97],
#  [-5.823529411764696, -2.89, -6.64],
#  [-3.705882352941188, -2.04, -6.02],
#  [-5.823529411764696, -3.14, -5.23],
#  [-0.8823529411764639, -2.38, -5.29],
#  [-5.823529411764696, -1.59, -6.82],
#  [0.529411764705884, -2.83, -6.12],
#  [-7.235294117647072, -2.74, -6.65],
#  [-7.941176470588232, -2.66, -5.47],
#  [-1.588235294117652, -2.0, -6.55],
#  [-3.705882352941188, -1.97, -7.51],
#  [-0.8823529411764639, -2.45, -7.15],
#  [-3.705882352941188, -2.87, -7.15],
#  [-1.588235294117652, -2.68, -6.95],
#  [-3.0, -2.76, -5.98],
#  [-2.2941176470588402, -1.31, -7.32],
#  [-6.529411764705884, -2.03, -6.41],
#  [-5.117647058823536, -3.1, -5.85],
#  [-2.2941176470588402, -1.9, -7.68],
#  [-5.117647058823536, -2.98, -6.14],
#  [-0.8823529411764639, -2.21, -5.87],
#  [-0.17647058823530415, -1.99, -6.02],
#  [-3.0, -1.32, -6.36],
#  [1.2352941176470722, -2.25, -6.97],
#  [-1.588235294117652, -2.72, -5.84],
#  [-0.17647058823530415, -2.51, -5.99],
#  [-1.588235294117652, -2.44, -7.23],
#  [0.529411764705884, -2.21, -6.78],
#  [-5.117647058823536, -3.11, -5.11],
#  [-3.0, -1.27, -6.4],
#  [-0.17647058823530415, -1.53, -6.13],
#  [-3.705882352941188, -2.51, -6.07],
#  [-3.0, -2.4, -6.77],
#  [-7.941176470588232, -2.8, -6.75],
#  [-0.8823529411764639, -3.27, -6.32],
#  [-4.411764705882348, -2.71, -6.37],
#  [-3.0, -2.62, -6.26],
#  [-3.0, -2.26, -6.39],
#  [-5.117647058823536, -2.18, -6.67],
#  [-0.8823529411764639, -2.57, -6.19],
#  [-1.588235294117652, -2.5, -6.15],
#  [-3.0, -2.02, -6.54],
#  [-4.411764705882348, -2.83, -6.61],
#  [1.2352941176470722, -1.05, -7.11],
#  [-1.588235294117652, -2.63, -6.19],
#  [-3.0, -2.4, -6.55],
#  [1.2352941176470722, -1.67, -7.33],
#  [-0.8823529411764639, -2.21, -6.52],
#  [-2.2941176470588402, -2.9, -6.85],
#  [1.2352941176470722, -2.01, -5.98],
#  [-4.411764705882348, -2.31, -6.18],
#  [-4.411764705882348, -2.75, -6.44],
#  [-0.17647058823530415, -2.75, -5.53],
#  [-2.2941176470588402, -1.73, -7.23],
#  [-4.411764705882348, -1.86, -6.73],
#  [-2.2941176470588402, -2.47, -5.59],
#  [1.2352941176470722, -1.49, -5.77],
#  [-2.2941176470588402, -3.44, -4.73],
#  [-0.8823529411764639, -1.49, -6.22],
#  [1.2352941176470722, -1.34, -6.82],
#  [1.941176470588232, -1.92, -7.08],
#  [-0.17647058823530415, -2.8, -7.13],
#  [-0.8823529411764639, -2.18, -6.38],
#  [-3.705882352941188, -1.49, -6.34],
#  [-3.0, -2.04, -6.9],
#  [-2.2941176470588402, -1.06, -6.38],
#  [-0.8823529411764639, -2.04, -6.24],
#  [-3.705882352941188, -2.22, -6.88],
#  [-4.411764705882348, -2.1, -7.84],
#  [-1.588235294117652, -2.54, -5.65],
#  [-4.411764705882348, -2.6, -6.33],
#  [-5.117647058823536, -2.6, -6.01],
#  [-3.0, -2.11, -7.01],
#  [-3.0, -2.47, -6.77],
#  [-4.411764705882348, -2.02, -5.9],
#  [-1.588235294117652, -2.39, -7.11],
#  [-0.8823529411764639, -2.74, -6.61],
#  [-5.117647058823536, -2.01, -5.84],
#  [-2.2941176470588402, -2.1, -6.56],
#  [-4.411764705882348, -2.8, -6.3],
#  [-0.8823529411764639, -2.81, -7.49],
#  [-1.588235294117652, -2.2, -5.81],
#  [-2.2941176470588402, -2.28, -6.07],
#  [-4.411764705882348, -2.34, -6.52],
#  [-1.588235294117652, -3.17, -5.82],
#  [-4.411764705882348, -2.78, -5.61],
#  [-0.8823529411764639, -1.44, -6.18],
#  [-4.411764705882348, -2.7, -6.76],
#  [-7.235294117647072, -2.96, -7.29],
#  [-2.2941176470588402, -3.47, -5.57],
#  [-0.8823529411764639, -1.69, -5.81],
#  [-3.0, -2.89, -5.53],
#  [-4.411764705882348, -1.85, -5.88],
#  [-2.2941176470588402, -2.5, -6.64],
#  [-3.0, -2.14, -6.29],
#  [-6.529411764705884, -3.15, -6.27],
#  [-2.2941176470588402, -3.14, -6.36],
#  [-1.588235294117652, -2.18, -6.65],
#  [-1.588235294117652, -1.57, -6.37],
#  [-4.411764705882348, -3.2, -5.32],
#  [0.529411764705884, -2.62, -6.19],
#  [-3.0, -3.0, -6.1],
#  [-7.235294117647072, -3.4, -5.75],
#  [-5.117647058823536, -2.31, -6.65],
#  [-4.411764705882348, -2.21, -6.34],
#  [-4.411764705882348, -2.75, -6.49],
#  [-1.588235294117652, -1.93, -5.98],
#  [-1.588235294117652, -1.39, -6.85],
#  [-1.588235294117652, -2.86, -7.11],
#  [0.529411764705884, -1.45, -6.73],
#  [-0.8823529411764639, -2.61, -7.38],
#  [-0.17647058823530415, -2.65, -5.75],
#  [0.529411764705884, -1.61, -6.16],
#  [0.529411764705884, -2.27, -6.13],
#  [-2.2941176470588402, -2.84, -5.79],
#  [-2.2941176470588402, -1.87, -6.79],
#  [-0.8823529411764639, -1.8, -8.24],
#  [-5.117647058823536, -2.63, -6.27],
#  [1.941176470588232, -2.51, -7.41],
#  [-0.8823529411764639, -1.72, -5.56],
#  [-2.2941176470588402, -2.29, -6.32],
#  [0.529411764705884, -2.2, -7.09],
#  [-0.17647058823530415, -1.47, -6.81],
#  [-3.0, -2.82, -6.76],
#  [1.941176470588232, -2.11, -6.85],
#  [-4.411764705882348, -2.72, -5.9],
#  [1.2352941176470722, -2.73, -6.34],
#  [-3.0, -1.17, -6.71],
#  [-5.823529411764696, -2.04, -7.06],
#  [-5.117647058823536, -2.92, -4.91],
#  [1.2352941176470722, -1.98, -6.05],
#  [-4.411764705882348, -3.05, -5.79],
#  [-3.0, -2.25, -7.64],
#  [-2.2941176470588402, -1.93, -6.38],
#  [-5.117647058823536, -2.54, -6.29],
#  [-0.8823529411764639, -1.52, -6.98],
#  [-5.117647058823536, -3.2, -4.86],
#  [1.2352941176470722, -2.62, -5.31],
#  [-5.117647058823536, -2.95, -5.87],
#  [-3.0, -2.42, -6.92],
#  [-5.117647058823536, -2.85, -5.96],
#  [-2.2941176470588402, -2.19, -6.21],
#  [-1.588235294117652, -1.88, -7.12],
#  [-1.588235294117652, -2.44, -5.77],
#  [-3.705882352941188, -2.04, -7.29],
#  [-3.705882352941188, -2.62, -6.64],
#  [-5.823529411764696, -3.82, -6.15],
#  [-5.117647058823536, -2.1, -6.04],
#  [-3.705882352941188, -2.61, -7.02],
#  [-3.705882352941188, -3.28, -3.99],
#  [-3.705882352941188, -2.39, -6.37],
#  [-2.2941176470588402, -2.21, -6.76],
#  [-2.2941176470588402, -2.48, -6.52],
#  [-3.705882352941188, -1.9, -5.47],
#  [-7.235294117647072, -2.78, -6.13],
#  [-3.705882352941188, -2.4, -5.88],
#  [-4.411764705882348, -2.07, -6.02],
#  [-5.823529411764696, -2.94, -5.84],
#  [-0.17647058823530415, -1.7, -7.05],
#  [-3.705882352941188, -2.9, -5.5],
#  [-0.17647058823530415, -2.98, -6.3],
#  [-4.411764705882348, -2.1, -6.14],
#  [-2.2941176470588402, -3.06, -7.05],
#  [-3.705882352941188, -3.12, -6.37],
#  [-2.2941176470588402, -2.81, -6.54],
#  [-0.8823529411764639, -2.34, -6.53],
#  [-3.0, -1.79, -5.82],
#  [-5.117647058823536, -2.71, -6.69],
#  [-2.2941176470588402, -2.04, -7.39],
#  [-0.17647058823530415, -1.81, -7.48],
#  [-3.0, -1.93, -5.72],
#  [-1.588235294117652, -1.9, -7.16],
#  [-5.117647058823536, -2.76, -5.81],
#  [-4.411764705882348, -2.71, -6.88],
#  [-2.2941176470588402, -2.48, -6.59],
#  [-2.2941176470588402, -2.23, -6.18],
#  [-0.17647058823530415, -1.67, -6.3],
#  [-4.411764705882348, -2.63, -6.15],
#  [-5.117647058823536, -2.72, -7.11],
#  [1.941176470588232, -2.9, -6.99],
#  [-7.941176470588232, -2.21, -6.21],
#  [-2.2941176470588402, -2.36, -5.66],
#  [-5.117647058823536, -1.28, -6.99],
#  [-3.0, -1.65, -6.55],
#  [-0.17647058823530415, -2.64, -6.48],
#  [-3.705882352941188, -1.62, -8.0],
#  [-3.0, -2.51, -5.91],
#  [-3.0, -2.18, -7.06],
#  [-2.2941176470588402, -2.93, -6.66],
#  [-0.8823529411764639, -2.35, -7.0],
#  [-3.0, -2.88, -5.8],
#  [-0.17647058823530415, -1.91, -7.24],
#  [-0.8823529411764639, -2.11, -6.71],
#  [0.529411764705884, -3.15, -7.1],
#  [-0.8823529411764639, -2.74, -6.52],
#  [-3.705882352941188, -2.39, -6.84],
#  [-3.705882352941188, -3.18, -6.3],
#  [0.529411764705884, -2.33, -5.57],
#  [-3.705882352941188, -1.94, -5.89],
#  [-1.588235294117652, -2.23, -6.59],
#  [-0.8823529411764639, -1.58, -5.04],
#  [-3.705882352941188, -1.98, -6.07],
#  [-2.2941176470588402, -2.07, -6.69],
#  [-0.17647058823530415, -1.33, -5.74],
#  [-3.0, -1.38, -6.62],
#  [-4.411764705882348, -1.64, -6.6],
#  [-4.411764705882348, -2.42, -6.68],
#  [-3.0, -2.05, -7.86],
#  [-3.705882352941188, -2.16, -7.41],
#  [-4.411764705882348, -1.91, -8.34],
#  [-0.8823529411764639, -3.13, -6.03],
#  [-1.588235294117652, -2.41, -5.91],
#  [-0.17647058823530415, -2.78, -5.54],
#  [-5.823529411764696, -1.85, -7.58],
#  [-0.8823529411764639, -2.08, -6.57],
#  [-5.117647058823536, -1.96, -6.97],
#  [-0.8823529411764639, -2.67, -5.94],
#  [-2.2941176470588402, -2.72, -6.32],
#  [-0.8823529411764639, -2.19, -6.44],
#  [1.2352941176470722, -2.87, -7.1],
#  [-2.2941176470588402, -1.61, -5.58],
#  [-1.588235294117652, -1.88, -6.49],
#  [-3.705882352941188, -1.57, -6.75],
#  [-0.17647058823530415, -1.9, -6.12],
#  [0.529411764705884, -2.82, -7.15],
#  [-3.0, -2.47, -6.49],
#  [-3.705882352941188, -3.44, -6.61],
#  [-0.8823529411764639, -2.44, -5.77],
#  [-3.0, -1.74, -6.94],
#  [-6.529411764705884, -3.8, -6.18],
#  [-2.2941176470588402, -2.24, -5.76],
#  [-1.588235294117652, -2.55, -5.44],
#  [-5.823529411764696, -2.35, -6.5],
#  [-3.705882352941188, -2.05, -5.86],
#  [-2.2941176470588402, -1.79, -6.76],
#  [-0.17647058823530415, -2.8, -5.96],
#  [-2.2941176470588402, -2.04, -6.01],
#  [-3.705882352941188, -2.74, -5.69],
#  [-3.0, -2.23, -6.03],
#  [-5.117647058823536, -1.89, -6.77],
#  [-1.588235294117652, -2.99, -5.96],
#  [-0.17647058823530415, -2.37, -6.06],
#  [-5.117647058823536, -2.37, -5.08],
#  [-3.705882352941188, -2.58, -6.71],
#  [-3.0, -2.88, -6.91],
#  [-4.411764705882348, -1.38, -6.79],
#  [-1.588235294117652, -1.63, -6.77],
#  [-1.588235294117652, -1.86, -6.34],
#  [-2.2941176470588402, -2.5, -6.26],
#  [-2.2941176470588402, -2.98, -6.1],
#  [-1.588235294117652, -2.0, -5.84],
#  [-3.705882352941188, -1.04, -6.5],
#  [-3.705882352941188, -3.03, -6.6],
#  [-0.17647058823530415, -1.9, -6.8],
#  [-2.2941176470588402, -2.66, -6.23],
#  [1.2352941176470722, -2.96, -5.78],
#  [-2.2941176470588402, -1.93, -7.0],
#  [1.2352941176470722, -2.18, -6.19],
#  [-1.588235294117652, -3.24, -6.02],
#  [-2.2941176470588402, -3.56, -5.88],
#  [-5.117647058823536, -2.89, -6.11],
#  [-2.2941176470588402, -2.98, -6.2],
#  [-4.411764705882348, -2.17, -5.78],
#  [-1.588235294117652, -2.71, -6.06],
#  [-3.0, -1.94, -6.73],
#  [-3.705882352941188, -2.28, -5.51]]

# %%
biases_o2_d02=[]


for sim in range(300):
    interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y  =  simulation_o2(totalTime=6650,
                                                                                                              targ_onset = 550, 
                                                                                                              dist_onset=200, 
                                                                                                              presentation_period=250, 
                                                                                                              separation=4, 
                                                                                                              inhib_curr=True, 
                                                                                                              time_ex_input=0, 
                                                                                                              sigE=0.7, 
                                                                                                              plot_connectivity=False,
                                                                                                              plot_dyniamic=False,
                                                                                                              plot_heatmap=False, 
                                                                                                              plot_fit=False )


    biases_o2_d02.append([interference, bias_target, bias_dist])
# Out:
# Simulation time: 26.0s
# Simulation time: 26.1s
# Simulation time: 26.0s
# Simulation time: 26.2s
# Simulation time: 27.0s
# Simulation time: 25.7s
# Simulation time: 26.6s
# Simulation time: 26.1s
# Simulation time: 26.0s
# Simulation time: 26.0s
# Simulation time: 27.3s
# Simulation time: 25.9s
# Simulation time: 26.1s
# Simulation time: 25.9s
# Simulation time: 26.1s
# Simulation time: 26.0s
# Simulation time: 26.0s
# Simulation time: 27.6s
# Simulation time: 26.0s
# Simulation time: 26.0s
# Simulation time: 25.9s
# Simulation time: 26.6s
# Simulation time: 27.0s
# Simulation time: 25.7s
# Simulation time: 25.9s
# Simulation time: 26.1s
# Simulation time: 26.0s
# Simulation time: 26.7s
# Simulation time: 25.9s
# Simulation time: 26.8s
# Simulation time: 25.7s
# Simulation time: 26.4s
# Simulation time: 25.9s
# Simulation time: 26.6s
# Simulation time: 26.8s
# Simulation time: 26.2s
# Simulation time: 26.0s
# Simulation time: 25.8s
# Simulation time: 26.1s
# Simulation time: 25.8s
# Simulation time: 27.0s
# Simulation time: 25.7s
# Simulation time: 26.3s
# Simulation time: 26.1s
# Simulation time: 26.1s
# Simulation time: 27.4s
# Simulation time: 25.8s
# Simulation time: 25.7s
# Simulation time: 25.9s
# Simulation time: 25.6s
# Simulation time: 26.9s
# Simulation time: 26.8s
# Simulation time: 26.6s
# Simulation time: 25.8s
# Simulation time: 26.0s
# Simulation time: 25.9s
# Simulation time: 26.2s
# Simulation time: 27.7s
# Simulation time: 25.7s
# Simulation time: 26.6s
# Simulation time: 25.6s
# Simulation time: 25.8s
# Simulation time: 25.9s
# Simulation time: 26.9s
# Simulation time: 26.1s
# Simulation time: 25.7s
# Simulation time: 25.7s
# Simulation time: 26.2s
# Simulation time: 26.2s
# Simulation time: 27.1s
# Simulation time: 25.8s
# Simulation time: 26.0s
# Simulation time: 26.6s
# Simulation time: 25.9s
# Simulation time: 27.2s
# Simulation time: 26.0s
# Simulation time: 26.4s
# Simulation time: 26.1s
# Simulation time: 25.9s
# Simulation time: 25.9s
# Simulation time: 25.8s
# Simulation time: 27.5s
# Simulation time: 25.6s
# Simulation time: 25.7s
# Simulation time: 26.1s
# Simulation time: 26.4s
# Simulation time: 26.9s
# Simulation time: 26.2s
# Simulation time: 25.7s
# Simulation time: 25.8s
# Simulation time: 26.1s
# Simulation time: 26.0s
# Simulation time: 26.2s
# Simulation time: 27.3s
# Simulation time: 26.1s
# Simulation time: 27.1s
# Simulation time: 25.5s
# Simulation time: 27.0s
# Simulation time: 25.6s
# Simulation time: 26.0s
# Simulation time: 25.8s
# Simulation time: 26.3s
# Simulation time: 25.9s
# Simulation time: 26.2s
# Simulation time: 32.6s
# Simulation time: 36.1s
# Simulation time: 40.0s
# Simulation time: 34.0s
# Simulation time: 31.4s
# Simulation time: 32.1s
# Simulation time: 31.3s
# Simulation time: 33.1s
# Simulation time: 32.3s
# Simulation time: 34.2s
# Simulation time: 36.6s
# Simulation time: 32.1s
# Simulation time: 34.0s
# Simulation time: 32.5s
# Simulation time: 34.5s
# Simulation time: 32.2s
# Simulation time: 34.1s
# Simulation time: 33.8s
# Simulation time: 31.8s
# Simulation time: 35.0s
# Simulation time: 37.4s
# Simulation time: 35.3s
# Simulation time: 32.9s
# Simulation time: 36.4s
# Simulation time: 33.3s
# Simulation time: 32.5s
# Simulation time: 36.5s
# Simulation time: 36.7s
# Simulation time: 35.2s
# Simulation time: 33.1s
# Simulation time: 38.7s
# Simulation time: 38.0s
# Simulation time: 32.8s
# Simulation time: 33.1s
# Simulation time: 35.5s
# Simulation time: 40.2s
# Simulation time: 37.2s
# Simulation time: 33.1s
# Simulation time: 38.6s
# Simulation time: 39.0s
# Simulation time: 33.2s
# Simulation time: 32.2s
# Simulation time: 35.8s
# Simulation time: 38.2s
# Simulation time: 33.3s
# Simulation time: 35.0s
# Simulation time: 37.5s
# Simulation time: 44.7s
# Simulation time: 33.5s
# Simulation time: 32.9s
# Simulation time: 36.5s
# Simulation time: 39.8s
# Simulation time: 33.0s
# Simulation time: 33.1s
# Simulation time: 38.4s
# Simulation time: 40.4s
# Simulation time: 33.8s
# Simulation time: 32.5s
# Simulation time: 35.4s
# Simulation time: 39.6s
# Simulation time: 34.2s
# Simulation time: 32.4s
# Simulation time: 36.0s
# Simulation time: 42.9s
# Simulation time: 34.1s
# Simulation time: 32.7s
# Simulation time: 35.4s
# Simulation time: 38.0s
# Simulation time: 32.6s
# Simulation time: 31.4s
# Simulation time: 34.0s
# Simulation time: 41.2s
# Simulation time: 32.6s
# Simulation time: 31.8s
# Simulation time: 34.6s
# Simulation time: 37.0s
# Simulation time: 32.7s
# Simulation time: 31.6s
# Simulation time: 33.9s
# Simulation time: 39.4s
# Simulation time: 37.3s
# Simulation time: 32.6s
# Simulation time: 33.3s
# Simulation time: 37.8s
# Simulation time: 34.6s
# Simulation time: 31.9s
# Simulation time: 33.6s
# Simulation time: 39.4s
# Simulation time: 36.5s
# Simulation time: 35.5s
# Simulation time: 33.7s
# Simulation time: 38.7s
# Simulation time: 35.6s
# Simulation time: 31.8s
# Simulation time: 32.8s
# Simulation time: 38.0s
# Simulation time: 39.9s
# Simulation time: 34.1s
# Simulation time: 35.4s
# Simulation time: 39.3s
# Simulation time: 37.1s
# Simulation time: 32.3s
# Simulation time: 31.9s
# Simulation time: 34.6s
# Simulation time: 37.5s
# Simulation time: 33.2s
# Simulation time: 33.2s
# Simulation time: 38.8s
# Simulation time: 36.2s
# Simulation time: 32.2s
# Simulation time: 31.2s
# Simulation time: 34.3s
# Simulation time: 35.1s
# Simulation time: 32.2s
# Simulation time: 33.4s
# Simulation time: 33.4s
# Simulation time: 39.1s
# Simulation time: 32.8s
# Simulation time: 33.2s
# Simulation time: 34.3s
# Simulation time: 40.2s
# Simulation time: 36.5s
# Simulation time: 34.6s
# Simulation time: 39.5s
# Simulation time: 36.3s
# Simulation time: 35.2s
# Simulation time: 32.4s
# Simulation time: 34.8s
# Simulation time: 37.9s
# Simulation time: 33.2s
# Simulation time: 32.9s
# Simulation time: 35.0s
# Simulation time: 38.7s
# Simulation time: 37.0s
# Simulation time: 34.9s
# Simulation time: 33.1s
# Simulation time: 37.4s
# Simulation time: 35.5s
# Simulation time: 32.4s
# Simulation time: 33.9s
# Simulation time: 39.7s
# Simulation time: 36.3s
# Simulation time: 33.2s
# Simulation time: 34.1s
# Simulation time: 36.8s
# Simulation time: 37.0s
# Simulation time: 32.9s
# Simulation time: 32.2s
# Simulation time: 36.8s
# Simulation time: 36.5s
# Simulation time: 32.7s
# Simulation time: 33.1s
# Simulation time: 35.8s
# Simulation time: 37.6s
# Simulation time: 32.6s
# Simulation time: 32.9s
# Simulation time: 35.7s
# Simulation time: 38.8s
# Simulation time: 32.5s
# Simulation time: 33.1s
# Simulation time: 38.6s
# Simulation time: 36.3s
# Simulation time: 32.6s
# Simulation time: 32.8s
# Simulation time: 36.3s
# Simulation time: 34.7s
# Simulation time: 32.2s
# Simulation time: 34.6s
# Simulation time: 38.8s
# Simulation time: 36.1s
# Simulation time: 31.9s
# Simulation time: 33.1s
# Simulation time: 37.4s
# Simulation time: 35.2s
# Simulation time: 33.3s
# Simulation time: 32.5s
# Simulation time: 36.2s
# Simulation time: 37.3s
# Simulation time: 34.2s
# Simulation time: 33.1s
# Simulation time: 35.4s
# Simulation time: 37.2s
# Simulation time: 34.6s
# Simulation time: 33.9s
# Simulation time: 38.1s
# Simulation time: 35.4s
# Simulation time: 31.9s
# Simulation time: 35.6s
# Simulation time: 38.3s
# Simulation time: 35.7s
# Simulation time: 33.4s
# Simulation time: 36.6s
# Simulation time: 39.4s
# Simulation time: 35.3s
# Simulation time: 32.0s
# Simulation time: 32.2s

# %%
biases_o2_d02
# Out:
# [[0.529411764705884, -0.7, -12.07],
#  [2.6470588235293917, -0.96, -80.47],
#  [0.529411764705884, -0.39, -78.91],
#  [1.941176470588232, -0.16, -80.86],
#  [4.764705882352928, 0.04, -79.77],
#  [-0.8823529411764639, -1.28, -11.35],
#  [-2.2941176470588402, -1.03, -9.62],
#  [-4.411764705882348, -2.2, -8.11],
#  [-0.8823529411764639, -0.77, -79.69],
#  [-0.8823529411764639, 0.11, 92.64],
#  [1.941176470588232, -1.22, -85.03],
#  [2.6470588235293917, -1.33, -10.7],
#  [1.2352941176470722, -1.0, -10.71],
#  [1.941176470588232, -0.96, -11.25],
#  [0.529411764705884, -1.3, -88.23],
#  [-0.17647058823530415, -0.73, -80.37],
#  [-4.411764705882348, -1.63, -14.15],
#  [-3.0, -0.49, -84.46],
#  [-1.588235294117652, -1.63, -9.11],
#  [-3.705882352941188, -1.28, -9.61],
#  [-2.2941176470588402, -1.87, -7.68],
#  [-4.411764705882348, -0.48, -84.56],
#  [-1.588235294117652, -0.77, -59.88],
#  [-0.8823529411764639, -0.93, 90.78],
#  [-5.117647058823536, -0.48, -89.27],
#  [-0.17647058823530415, -2.58, -10.65],
#  [2.6470588235293917, -0.55, -91.79],
#  [-0.8823529411764639, -0.51, -95.56],
#  [-0.17647058823530415, -1.28, -10.88],
#  [1.2352941176470722, -1.53, -8.82],
#  [1.2352941176470722, -1.54, -87.03],
#  [-0.17647058823530415, -0.09, -81.88],
#  [4.058823529411768, -1.47, -12.28],
#  [-4.411764705882348, -0.79, -12.25],
#  [0.529411764705884, -1.02, -83.94],
#  [0.529411764705884, -0.58, -76.35],
#  [-2.2941176470588402, -0.87, -47.51],
#  [-3.705882352941188, -0.92, -79.7],
#  [-1.588235294117652, -0.62, -49.8],
#  [-0.8823529411764639, -0.21, -74.3],
#  [0.529411764705884, -1.81, -9.63],
#  [-2.2941176470588402, -0.05, -92.44],
#  [3.35294117647058, -0.66, -49.84],
#  [-0.17647058823530415, -0.94, -62.8],
#  [-5.117647058823536, -0.8, -10.62],
#  [-2.2941176470588402, -2.01, -10.74],
#  [-3.0, 0.16, -86.86],
#  [-3.0, -1.11, -89.62],
#  [-1.588235294117652, -1.23, -90.64],
#  [3.35294117647058, -0.8, -12.09],
#  [1.2352941176470722, 0.32, -92.17],
#  [-3.0, -1.87, -65.25],
#  [-0.8823529411764639, -0.86, -103.83],
#  [-0.17647058823530415, -1.62, -10.87],
#  [1.2352941176470722, -0.7, -90.05],
#  [-3.705882352941188, -2.22, -8.5],
#  [-3.0, -1.42, -55.18],
#  [1.941176470588232, -1.7, -10.83],
#  [-4.411764705882348, -0.96, -12.05],
#  [1.941176470588232, -0.34, -12.86],
#  [-0.8823529411764639, -1.16, -59.77],
#  [0.529411764705884, -0.45, -73.03],
#  [4.764705882352928, -0.8, -86.85],
#  [4.764705882352928, -0.66, -84.73],
#  [-3.705882352941188, -1.6, -9.91],
#  [-3.0, -0.46, 58.34],
#  [-0.8823529411764639, -0.31, -10.98],
#  [1.941176470588232, -1.07, 94.15],
#  [-0.8823529411764639, -0.43, 79.24],
#  [-2.2941176470588402, -2.69, -9.08],
#  [0.529411764705884, 0.32, -87.39],
#  [1.941176470588232, -0.14, 87.73],
#  [-3.0, -1.15, -82.21],
#  [-3.0, -2.06, -8.95],
#  [-3.0, -1.34, -76.17],
#  [0.529411764705884, -0.81, -82.96],
#  [-1.588235294117652, -0.77, 94.45],
#  [0.529411764705884, -0.98, -10.74],
#  [-0.8823529411764639, -1.95, -11.26],
#  [-1.588235294117652, -2.33, -9.56],
#  [-2.2941176470588402, 0.18, 85.95],
#  [-1.588235294117652, -0.52, 90.42],
#  [-5.117647058823536, -1.11, -72.71],
#  [-0.8823529411764639, 0.81, 90.04],
#  [-5.117647058823536, -1.39, -11.43],
#  [-3.705882352941188, -1.77, -10.12],
#  [0.529411764705884, -1.03, -63.3],
#  [-0.17647058823530415, -0.89, -66.49],
#  [-4.411764705882348, -1.41, -13.14],
#  [0.529411764705884, -1.39, -93.98],
#  [2.6470588235293917, -0.89, -11.0],
#  [-1.588235294117652, 0.08, -66.04],
#  [-0.8823529411764639, -1.06, -13.74],
#  [-4.411764705882348, -0.72, -10.72],
#  [-3.0, -1.17, -9.65],
#  [1.2352941176470722, -0.28, -88.5],
#  [-0.17647058823530415, -1.53, 81.71],
#  [4.764705882352928, 0.08, 90.0],
#  [-1.588235294117652, -1.34, -12.14],
#  [0.529411764705884, 0.23, -71.73],
#  [-1.588235294117652, -0.17, -80.11],
#  [1.941176470588232, -0.21, -57.55],
#  [-0.17647058823530415, -1.43, -9.3],
#  [-6.529411764705884, -1.05, -10.52],
#  [-4.411764705882348, -1.76, -11.01],
#  [-3.0, -1.43, -73.77],
#  [5.470588235294116, -0.26, -86.8],
#  [-4.411764705882348, -0.91, -12.44],
#  [-2.2941176470588402, -1.02, -9.7],
#  [-2.2941176470588402, -0.76, -11.7],
#  [-3.705882352941188, -1.16, -13.4],
#  [-2.2941176470588402, 0.08, -84.33],
#  [-0.8823529411764639, -1.18, -82.29],
#  [-0.8823529411764639, -1.15, -77.01],
#  [1.2352941176470722, -0.44, -88.32],
#  [1.2352941176470722, -1.05, -13.94],
#  [-3.0, -0.6, -89.08],
#  [1.2352941176470722, -0.82, -12.73],
#  [-1.588235294117652, -1.82, -10.24],
#  [-1.588235294117652, -1.1, -90.1],
#  [-3.0, -0.92, -68.87],
#  [-0.8823529411764639, -1.05, -10.35],
#  [-4.411764705882348, -1.09, -82.37],
#  [1.941176470588232, -1.27, -72.17],
#  [-3.0, -2.41, -9.97],
#  [-4.411764705882348, -0.28, -86.75],
#  [-0.17647058823530415, 0.06, -88.66],
#  [-4.411764705882348, -1.04, -78.33],
#  [-0.17647058823530415, -1.22, -10.17],
#  [1.2352941176470722, -1.59, -9.81],
#  [3.35294117647058, -0.43, -9.04],
#  [-0.17647058823530415, -0.81, -86.29],
#  [0.529411764705884, -0.48, -76.78],
#  [-3.705882352941188, -1.62, -9.09],
#  [-2.2941176470588402, -0.64, -68.45],
#  [-1.588235294117652, -1.93, -10.25],
#  [-3.705882352941188, -0.69, -11.45],
#  [0.529411764705884, -1.81, -9.61],
#  [-5.117647058823536, -1.42, -71.45],
#  [-3.0, -1.61, -11.67],
#  [-3.705882352941188, -0.59, 94.25],
#  [-1.588235294117652, -0.67, -88.0],
#  [-0.17647058823530415, -1.39, -13.18],
#  [-1.588235294117652, -1.29, -81.35],
#  [-0.17647058823530415, -1.63, -10.97],
#  [-0.17647058823530415, -0.73, -81.08],
#  [-0.8823529411764639, 0.38, 89.17],
#  [0.529411764705884, -0.14, 61.72],
#  [-2.2941176470588402, -0.42, -82.47],
#  [-0.17647058823530415, -1.32, -78.33],
#  [-4.411764705882348, -1.33, -9.92],
#  [0.529411764705884, -0.85, -85.02],
#  [1.2352941176470722, -1.32, -95.77],
#  [-3.705882352941188, -0.72, -85.9],
#  [-0.8823529411764639, -1.66, -9.8],
#  [-0.17647058823530415, -0.92, -11.72],
#  [4.058823529411768, 0.7, 87.25],
#  [1.941176470588232, -0.92, -10.64],
#  [-1.588235294117652, -2.72, -9.07],
#  [-5.117647058823536, -2.05, 80.48],
#  [-0.8823529411764639, -1.22, -83.58],
#  [-3.705882352941188, -0.27, -92.2],
#  [-4.411764705882348, -1.32, -8.0],
#  [2.6470588235293917, -0.26, 83.73],
#  [3.35294117647058, -0.24, -95.57],
#  [-4.411764705882348, -1.79, 86.39],
#  [1.2352941176470722, -0.46, -74.84],
#  [-2.2941176470588402, -0.61, 82.66],
#  [-0.17647058823530415, -0.63, -74.77],
#  [2.6470588235293917, -0.1, 88.97],
#  [1.941176470588232, -0.29, 93.89],
#  [3.35294117647058, -1.21, -8.59],
#  [-3.705882352941188, -1.21, -86.78],
#  [-3.0, -0.84, -99.74],
#  [-4.411764705882348, -1.51, -9.39],
#  [1.2352941176470722, -0.47, -82.22],
#  [0.529411764705884, -1.72, -10.57],
#  [-3.705882352941188, -0.3, 87.73],
#  [1.941176470588232, -0.69, -11.42],
#  [-0.8823529411764639, -0.96, -10.37],
#  [-2.2941176470588402, -1.14, -14.37],
#  [-3.0, -1.14, -11.87],
#  [0.529411764705884, -2.26, -9.0],
#  [-0.8823529411764639, -0.69, -71.07],
#  [-2.2941176470588402, -1.41, -9.18],
#  [1.2352941176470722, -0.75, -10.02],
#  [-5.117647058823536, -0.27, -10.25],
#  [-4.411764705882348, -1.32, -8.83],
#  [-2.2941176470588402, -1.87, -8.96],
#  [-2.2941176470588402, -2.28, -9.14],
#  [-2.2941176470588402, -2.02, -11.75],
#  [-2.2941176470588402, 0.43, -85.86],
#  [-2.2941176470588402, -0.98, -11.57],
#  [0.529411764705884, -0.07, 77.37],
#  [-1.588235294117652, -1.34, -76.04],
#  [-3.705882352941188, -1.65, -85.28],
#  [-3.705882352941188, -0.82, -70.3],
#  [0.529411764705884, -2.1, -9.26],
#  [0.529411764705884, -0.64, -63.32],
#  [-2.2941176470588402, -1.6, -8.7],
#  [-2.2941176470588402, -0.56, -11.15],
#  [-0.17647058823530415, -1.26, -11.07],
#  [-2.2941176470588402, -1.08, -76.16],
#  [0.529411764705884, -0.61, -63.43],
#  [-5.823529411764696, -2.3, -8.8],
#  [-4.411764705882348, -1.01, -14.66],
#  [-0.17647058823530415, -1.14, -59.29],
#  [-4.411764705882348, -0.54, -10.92],
#  [0.529411764705884, -1.8, -8.3],
#  [-1.588235294117652, -0.74, -92.98],
#  [-1.588235294117652, -1.0, -95.33],
#  [-3.0, -1.37, 82.48],
#  [-3.0, -0.37, 93.86],
#  [-7.235294117647072, -1.17, -86.37],
#  [-1.588235294117652, 0.14, -86.96],
#  [-1.588235294117652, -0.53, -89.44],
#  [-3.0, -1.54, -8.6],
#  [-6.529411764705884, -2.37, -10.19],
#  [0.529411764705884, -1.15, -79.6],
#  [-3.705882352941188, -1.45, -79.37],
#  [-4.411764705882348, -1.56, -61.09],
#  [-7.235294117647072, -0.94, -74.05],
#  [5.470588235294116, -0.8, -9.33],
#  [-0.8823529411764639, -1.34, -10.97],
#  [-3.705882352941188, -2.48, -11.21],
#  [1.2352941176470722, -0.64, -94.51],
#  [-2.2941176470588402, -0.78, -12.44],
#  [-2.2941176470588402, -1.08, 92.56],
#  [-1.588235294117652, -1.83, -8.87],
#  [2.6470588235293917, 0.53, -96.82],
#  [-0.8823529411764639, -0.84, -12.2],
#  [-1.588235294117652, -1.18, -11.18],
#  [3.35294117647058, 0.4, 80.82],
#  [-4.411764705882348, -0.45, -12.82],
#  [1.941176470588232, -0.56, 83.98],
#  [-4.411764705882348, -0.1, -78.34],
#  [-1.588235294117652, -1.49, -72.54],
#  [-1.588235294117652, -1.2, -10.03],
#  [0.529411764705884, -0.47, -57.91],
#  [2.6470588235293917, -0.35, -96.05],
#  [-2.2941176470588402, -1.19, -12.02],
#  [-3.0, -1.1, -60.69],
#  [-0.17647058823530415, -1.96, -9.66],
#  [2.6470588235293917, -1.15, -73.53],
#  [-1.588235294117652, -1.51, -13.09],
#  [1.2352941176470722, -0.91, -70.64],
#  [-3.705882352941188, -1.25, -80.72],
#  [-0.17647058823530415, -1.12, -85.02],
#  [-1.588235294117652, -1.01, -80.83],
#  [-0.17647058823530415, -0.22, -75.07],
#  [1.2352941176470722, -1.52, -12.64],
#  [1.941176470588232, -1.03, -10.17],
#  [-0.17647058823530415, -1.14, -12.26],
#  [1.2352941176470722, -0.44, -66.24],
#  [-0.8823529411764639, -1.55, -12.17],
#  [3.35294117647058, -0.43, -84.17],
#  [-2.2941176470588402, -1.19, -91.9],
#  [0.529411764705884, -1.19, -86.53],
#  [-3.0, -1.55, -10.45],
#  [-1.588235294117652, -0.77, -10.56],
#  [-4.411764705882348, -1.79, -9.32],
#  [-2.2941176470588402, -1.15, -9.15],
#  [-5.823529411764696, -2.22, -9.68],
#  [-3.0, -0.6, -14.22],
#  [-1.588235294117652, 0.23, -88.72],
#  [1.2352941176470722, 0.27, 95.67],
#  [3.35294117647058, -0.42, -61.44],
#  [3.35294117647058, 0.1, 92.87],
#  [-0.8823529411764639, -0.49, 81.71],
#  [-4.411764705882348, -1.92, -9.84],
#  [-1.588235294117652, -0.36, -95.07],
#  [-6.529411764705884, -1.28, -9.96],
#  [-0.8823529411764639, -0.91, -71.28],
#  [-0.17647058823530415, -0.2, 93.08],
#  [-0.17647058823530415, -1.5, -10.74],
#  [2.6470588235293917, -1.41, -9.37],
#  [1.2352941176470722, 0.03, -87.09],
#  [-4.411764705882348, -1.43, -81.63],
#  [-0.8823529411764639, -1.35, -83.75],
#  [-1.588235294117652, 0.43, -92.47],
#  [-4.411764705882348, -2.85, -7.74],
#  [1.2352941176470722, 0.33, 84.51],
#  [-3.0, -2.0, -10.52],
#  [-5.117647058823536, -2.57, -10.51],
#  [-5.117647058823536, -0.31, -12.28],
#  [1.2352941176470722, -1.4, -8.9],
#  [1.941176470588232, -0.26, -84.91],
#  [0.529411764705884, -1.26, -76.6],
#  [-0.17647058823530415, -1.33, -10.89],
#  [-3.0, -1.46, -70.24],
#  [-0.17647058823530415, -1.36, -91.51],
#  [-1.588235294117652, -1.21, -72.31],
#  [-0.8823529411764639, -0.37, -11.15],
#  [-0.8823529411764639, -1.92, -10.88],
#  [1.2352941176470722, 0.13, -74.46],
#  [-3.0, -1.47, -8.05],
#  [-3.705882352941188, -0.97, -67.76],
#  [-5.117647058823536, -2.31, -7.81],
#  [-3.0, -0.47, -10.76],
#  [-5.117647058823536, -0.39, -13.5]]

# %%
biases_o2_d7=[]

for sim in range(300):
    interference, max_re, bias_target, bias_dist, number_of_bumps, targ_ang, dist_ang, X, y  = simulation_2_7(totalTime=9600,
                                                                                                              targ_onset = 3950,
                                                                                                              dist_onset=200, 
                                                                                                              presentation_period=250,
                                                                                                              separation=4, 
                                                                                                              inhib_curr=True, 
                                                                                                              time_ex_input=0, 
                                                                                                              sigE=0.7, 
                                                                                                              plot_connectivity=False, 
                                                                                                              plot_dyniamic=False, 
                                                                                                              plot_heatmap=False, 
                                                                                                              plot_fit=False )
    biases_o2_d7.append([interference, bias_target, bias_dist])
# Out:
# Simulation time: 55.2s
# Simulation time: 48.2s
# Simulation time: 47.7s
# Simulation time: 52.8s
# Simulation time: 47.2s
# Simulation time: 47.4s
# Simulation time: 55.9s
# Simulation time: 46.4s
# Simulation time: 50.7s
# Simulation time: 52.0s
# Simulation time: 46.0s
# Simulation time: 47.8s
# Simulation time: 52.6s
# Simulation time: 47.4s
# Simulation time: 53.4s
# Simulation time: 52.1s
# Simulation time: 45.5s
# Simulation time: 49.6s
# Simulation time: 51.2s
# Simulation time: 48.1s
# Simulation time: 51.6s
# Simulation time: 53.0s
# Simulation time: 45.8s
# Simulation time: 48.1s
# Simulation time: 53.8s
# Simulation time: 49.1s
# Simulation time: 50.2s
# Simulation time: 51.9s
# Simulation time: 46.5s
# Simulation time: 50.5s
# Simulation time: 50.5s
# Simulation time: 46.9s
# Simulation time: 51.8s
# Simulation time: 51.7s
# Simulation time: 45.9s
# Simulation time: 49.7s
# Simulation time: 50.7s
# Simulation time: 45.8s
# Simulation time: 56.3s
# Simulation time: 47.0s
# Simulation time: 48.3s
# Simulation time: 51.9s
# Simulation time: 45.4s
# Simulation time: 49.9s
# Simulation time: 54.8s
# Simulation time: 45.8s
# Simulation time: 53.7s
# Simulation time: 48.9s
# Simulation time: 47.0s
# Simulation time: 54.0s
# Simulation time: 51.2s
# Simulation time: 47.2s
# Simulation time: 52.8s
# Simulation time: 46.1s
# Simulation time: 47.7s
# Simulation time: 53.6s
# Simulation time: 48.6s
# Simulation time: 50.9s
# Simulation time: 52.8s
# Simulation time: 46.5s
# Simulation time: 53.5s
# Simulation time: 51.5s
# Simulation time: 48.2s
# Simulation time: 57.6s
# Simulation time: 47.7s
# Simulation time: 46.6s
# Simulation time: 55.2s
# Simulation time: 47.4s
# Simulation time: 51.0s
# Simulation time: 57.3s
# Simulation time: 46.0s
# Simulation time: 46.9s
# Simulation time: 54.0s
# Simulation time: 47.2s
# Simulation time: 47.4s
# Simulation time: 56.0s
# Simulation time: 48.5s
# Simulation time: 47.6s
# Simulation time: 53.4s
# Simulation time: 47.1s
# Simulation time: 52.1s
# Simulation time: 55.6s
# Simulation time: 46.3s
# Simulation time: 51.0s
# Simulation time: 51.8s
# Simulation time: 45.8s
# Simulation time: 53.5s
# Simulation time: 53.2s
# Simulation time: 46.2s
# Simulation time: 52.0s
# Simulation time: 49.2s
# Simulation time: 46.9s
# Simulation time: 56.3s
# Simulation time: 47.2s
# Simulation time: 49.7s
# Simulation time: 51.1s
# Simulation time: 45.3s
# Simulation time: 51.5s
# Simulation time: 53.4s
# Simulation time: 46.0s
# Simulation time: 56.3s
# Simulation time: 48.7s
# Simulation time: 46.4s
# Simulation time: 53.4s
# Simulation time: 50.2s
# Simulation time: 45.5s
# Simulation time: 54.8s
# Simulation time: 45.4s
# Simulation time: 46.5s
# Simulation time: 51.0s
# Simulation time: 46.4s
# Simulation time: 52.3s
# Simulation time: 49.9s
# Simulation time: 48.1s
# Simulation time: 52.1s
# Simulation time: 48.6s
# Simulation time: 47.9s
# Simulation time: 53.3s
# Simulation time: 48.7s
# Simulation time: 48.3s
# Simulation time: 53.0s
# Simulation time: 48.1s
# Simulation time: 48.2s
# Simulation time: 52.6s
# Simulation time: 47.4s
# Simulation time: 48.0s
# Simulation time: 52.7s
# Simulation time: 47.7s
# Simulation time: 47.0s
# Simulation time: 52.8s
# Simulation time: 47.9s
# Simulation time: 45.5s
# Simulation time: 54.8s
# Simulation time: 47.5s
# Simulation time: 47.6s
# Simulation time: 53.7s
# Simulation time: 48.5s
# Simulation time: 46.8s
# Simulation time: 55.2s
# Simulation time: 47.4s
# Simulation time: 51.4s
# Simulation time: 54.5s
# Simulation time: 46.2s
# Simulation time: 51.5s
# Simulation time: 54.3s
# Simulation time: 45.5s
# Simulation time: 51.9s
# Simulation time: 44.8s
# Simulation time: 36.6s
# Simulation time: 38.1s
# Simulation time: 37.9s
# Simulation time: 37.8s
# Simulation time: 36.5s
# Simulation time: 36.7s
# Simulation time: 38.1s
# Simulation time: 36.9s
# Simulation time: 37.3s
# Simulation time: 37.8s
# Simulation time: 37.0s
# Simulation time: 36.9s
# Simulation time: 38.5s
# Simulation time: 37.6s
# Simulation time: 38.1s
# Simulation time: 37.0s
# Simulation time: 36.8s
# Simulation time: 35.9s
# Simulation time: 36.2s
# Simulation time: 36.8s
# Simulation time: 38.7s
# Simulation time: 36.9s
# Simulation time: 37.6s
# Simulation time: 37.3s
# Simulation time: 36.9s
# Simulation time: 36.8s
# Simulation time: 36.8s
# Simulation time: 36.8s
# Simulation time: 38.2s
# Simulation time: 37.0s
# Simulation time: 38.1s
# Simulation time: 36.1s
# Simulation time: 36.7s
# Simulation time: 36.1s
# Simulation time: 37.1s
# Simulation time: 37.0s
# Simulation time: 36.5s
# Simulation time: 38.8s
# Simulation time: 37.9s
# Simulation time: 36.6s
# Simulation time: 36.9s
# Simulation time: 37.0s
# Simulation time: 37.2s
# Simulation time: 36.9s
# Simulation time: 36.9s
# Simulation time: 38.2s
# Simulation time: 38.3s
# Simulation time: 37.0s
# Simulation time: 36.4s
# Simulation time: 36.2s
# Simulation time: 36.4s
# Simulation time: 36.2s
# Simulation time: 36.6s
# Simulation time: 37.1s
# Simulation time: 38.5s
# Simulation time: 36.4s
# Simulation time: 36.5s
# Simulation time: 38.3s
# Simulation time: 36.7s
# Simulation time: 37.1s
# Simulation time: 36.5s
# Simulation time: 37.1s
# Simulation time: 40.0s
# Simulation time: 36.3s
# Simulation time: 36.6s
# Simulation time: 36.3s
# Simulation time: 36.6s
# Simulation time: 36.2s
# Simulation time: 36.4s
# Simulation time: 36.6s
# Simulation time: 39.4s
# Simulation time: 36.6s
# Simulation time: 36.7s
# Simulation time: 36.7s
# Simulation time: 36.6s
# Simulation time: 36.4s
# Simulation time: 36.7s
# Simulation time: 37.0s
# Simulation time: 37.5s
# Simulation time: 38.8s
# Simulation time: 36.3s
# Simulation time: 36.5s
# Simulation time: 36.7s
# Simulation time: 36.6s
# Simulation time: 36.4s
# Simulation time: 36.6s
# Simulation time: 38.0s
# Simulation time: 38.6s
# Simulation time: 37.2s
# Simulation time: 36.8s
# Simulation time: 36.6s
# Simulation time: 36.5s
# Simulation time: 36.8s
# Simulation time: 37.3s
# Simulation time: 36.3s
# Simulation time: 38.3s
# Simulation time: 37.3s
# Simulation time: 36.5s
# Simulation time: 37.0s
# Simulation time: 36.4s
# Simulation time: 36.8s
# Simulation time: 36.7s
# Simulation time: 37.2s
# Simulation time: 37.9s
# Simulation time: 38.2s
# Simulation time: 36.9s
# Simulation time: 36.8s
# Simulation time: 37.0s
# Simulation time: 36.3s
# Simulation time: 37.7s
# Simulation time: 38.0s
# Simulation time: 37.4s
# Simulation time: 49.0s
# Simulation time: 37.7s
# Simulation time: 36.4s
# Simulation time: 36.4s
# Simulation time: 36.3s
# Simulation time: 36.4s
# Simulation time: 37.2s
# Simulation time: 36.9s
# Simulation time: 38.5s
# Simulation time: 36.3s
# Simulation time: 36.7s
# Simulation time: 36.7s
# Simulation time: 36.7s
# Simulation time: 36.9s
# Simulation time: 36.5s
# Simulation time: 37.5s
# Simulation time: 36.3s
# Simulation time: 38.2s
# Simulation time: 37.1s
# Simulation time: 36.5s
# Simulation time: 36.9s
# Simulation time: 36.8s
# Simulation time: 37.3s
# Simulation time: 37.9s
# Simulation time: 36.6s
# Simulation time: 37.7s
# Simulation time: 36.7s
# Simulation time: 36.5s
# Simulation time: 36.2s
# Simulation time: 36.7s
# Simulation time: 36.3s
# Simulation time: 38.1s
# Simulation time: 37.3s
# Simulation time: 37.4s
# Simulation time: 37.4s
# Simulation time: 36.8s
# Simulation time: 36.9s
# Simulation time: 36.7s
# Simulation time: 36.8s
# Simulation time: 37.7s

# %%
biases_o2_d7
# Out:
# [[-2.2941176470588402, -0.02, 64.36],
#  [-5.117647058823536, -1.05, -15.11],
#  [1.2352941176470722, 1.04, 68.45],
#  [-1.588235294117652, -0.88, 82.07],
#  [2.6470588235293917, 0.27, 31.49],
#  [-0.8823529411764639, -0.85, 79.67],
#  [-7.235294117647072, 0.01, -75.64],
#  [-5.117647058823536, -0.41, 84.58],
#  [1.2352941176470722, -0.06, 32.89],
#  [-3.0, -0.09, 79.32],
#  [-3.705882352941188, -0.73, -13.12],
#  [1.2352941176470722, 0.19, 82.28],
#  [2.6470588235293917, -0.02, 52.95],
#  [1.2352941176470722, -0.9, 102.23],
#  [2.6470588235293917, -1.14, -96.09],
#  [0.529411764705884, -0.59, -70.42],
#  [-7.235294117647072, -1.66, 59.23],
#  [0.529411764705884, -1.1, 53.44],
#  [0.529411764705884, 0.45, 36.54],
#  [1.941176470588232, -0.4, 36.62],
#  [0.529411764705884, -1.05, 80.46],
#  [-2.2941176470588402, -0.24, 58.78],
#  [1.941176470588232, 0.52, 80.19],
#  [0.529411764705884, -0.04, -59.72],
#  [-0.8823529411764639, -1.11, 57.44],
#  [3.35294117647058, -0.33, 31.39],
#  [-2.2941176470588402, -1.78, 35.16],
#  [-3.705882352941188, -0.29, -87.93],
#  [1.2352941176470722, -0.74, 72.61],
#  [4.764705882352928, 0.01, 36.01],
#  [-4.411764705882348, -0.84, 30.82],
#  [-2.2941176470588402, 0.55, 60.17],
#  [-3.0, 0.01, 76.36],
#  [3.35294117647058, -1.0, -81.18],
#  [-0.8823529411764639, -1.11, -81.48],
#  [-3.0, -0.58, 56.92],
#  [-0.17647058823530415, 0.39, 73.18],
#  [1.2352941176470722, -0.18, 70.66],
#  [1.2352941176470722, 0.05, 73.32],
#  [2.6470588235293917, 0.65, 76.25],
#  [-0.17647058823530415, -0.54, 85.79],
#  [-0.17647058823530415, 0.43, -99.52],
#  [-2.2941176470588402, -0.49, 82.73],
#  [0.529411764705884, 0.38, 79.24],
#  [-3.0, 0.43, 87.07],
#  [0.529411764705884, -0.49, 29.17],
#  [1.2352941176470722, -0.11, 50.04],
#  [-0.8823529411764639, -0.48, 33.0],
#  [-2.2941176470588402, -0.48, 94.93],
#  [0.529411764705884, -0.47, -96.34],
#  [-2.2941176470588402, -1.42, -42.88],
#  [-1.588235294117652, -0.36, 95.07],
#  [1.941176470588232, -0.57, 66.77],
#  [1.2352941176470722, -0.76, -77.96],
#  [-1.588235294117652, -0.33, 71.32],
#  [-0.17647058823530415, -0.97, 71.75],
#  [-5.117647058823536, -1.08, 88.38],
#  [-2.2941176470588402, -1.12, -58.73],
#  [-1.588235294117652, -0.83, 51.39],
#  [3.35294117647058, -0.56, -78.08],
#  [4.764705882352928, 0.37, -82.51],
#  [-2.2941176470588402, -0.7, 30.94],
#  [-1.588235294117652, -0.55, -60.63],
#  [4.764705882352928, -0.16, -91.19],
#  [-0.17647058823530415, -0.81, 54.95],
#  [-0.8823529411764639, -0.9, 32.54],
#  [-5.823529411764696, -0.28, 51.32],
#  [-0.17647058823530415, -0.57, 70.33],
#  [-1.588235294117652, -0.02, -90.11],
#  [1.941176470588232, -0.72, 66.56],
#  [-4.411764705882348, -0.08, 35.24],
#  [0.529411764705884, 0.06, 31.5],
#  [-0.17647058823530415, 0.21, 58.96],
#  [1.2352941176470722, -0.27, -19.9],
#  [2.6470588235293917, -0.1, 28.88],
#  [0.529411764705884, -0.04, -48.06],
#  [-3.705882352941188, -0.44, 33.86],
#  [-2.2941176470588402, 0.41, 85.27],
#  [-0.17647058823530415, -0.35, -17.96],
#  [-3.705882352941188, -0.76, -14.57],
#  [-2.2941176470588402, -1.38, -15.89],
#  [-4.411764705882348, -0.97, 87.67],
#  [0.529411764705884, -0.3, -20.08],
#  [-0.8823529411764639, -1.08, -87.62],
#  [-0.8823529411764639, -0.4, 33.5],
#  [-0.8823529411764639, -0.74, -15.31],
#  [-0.17647058823530415, -0.7, 31.51],
#  [0.529411764705884, -1.91, -12.74],
#  [-1.588235294117652, -1.09, -94.73],
#  [3.35294117647058, 0.29, -108.29],
#  [3.35294117647058, -0.21, 86.67],
#  [1.2352941176470722, -0.97, 30.44],
#  [-0.17647058823530415, -0.99, -78.24],
#  [2.6470588235293917, 0.02, 32.87],
#  [-7.941176470588232, -0.82, 29.74],
#  [4.058823529411768, 0.74, 50.39],
#  [0.529411764705884, -0.42, 32.17],
#  [-3.705882352941188, -0.04, -79.27],
#  [1.941176470588232, -1.2, -77.99],
#  [-0.8823529411764639, -0.61, 33.8],
#  [-0.17647058823530415, -0.54, -141.13],
#  [0.529411764705884, -1.25, 32.93],
#  [-0.8823529411764639, -1.02, -15.56],
#  [2.6470588235293917, 0.19, 45.18],
#  [-3.0, -1.0, 88.12],
#  [1.2352941176470722, -1.93, -19.44],
#  [1.941176470588232, -0.06, 88.47],
#  [-4.411764705882348, -0.58, 32.9],
#  [1.2352941176470722, -1.66, 30.26],
#  [1.941176470588232, 0.25, 81.24],
#  [3.35294117647058, -0.57, 52.99],
#  [3.35294117647058, 0.75, 85.0],
#  [-3.705882352941188, -0.52, 51.45],
#  [-0.8823529411764639, -1.23, 89.39],
#  [-0.17647058823530415, 0.4, 83.76],
#  [-2.2941176470588402, -0.53, 30.49],
#  [-1.588235294117652, -0.42, -87.24],
#  [-2.2941176470588402, 0.57, 27.21],
#  [-3.0, -1.72, -75.49],
#  [3.35294117647058, -1.07, -31.73],
#  [1.2352941176470722, -0.09, 68.97],
#  [6.882352941176464, -0.23, -95.77],
#  [1.2352941176470722, -0.89, 32.65],
#  [-4.411764705882348, -0.62, -70.49],
#  [4.058823529411768, -0.48, -72.15],
#  [-1.588235294117652, -0.67, 31.97],
#  [-1.588235294117652, -0.17, -84.84],
#  [-3.705882352941188, -0.21, 46.88],
#  [0.529411764705884, -0.34, -94.04],
#  [0.529411764705884, -0.81, -44.65],
#  [-2.2941176470588402, -0.43, 90.35],
#  [-4.411764705882348, -0.32, -69.64],
#  [2.6470588235293917, -0.59, 32.09],
#  [-0.17647058823530415, -0.61, 31.35],
#  [1.2352941176470722, 0.5, 30.46],
#  [-1.588235294117652, -0.25, 87.25],
#  [-0.8823529411764639, -1.07, 77.0],
#  [-3.0, 0.33, 85.73],
#  [-2.2941176470588402, -0.12, 39.84],
#  [-1.588235294117652, 0.1, 32.29],
#  [-1.588235294117652, -0.83, -81.3],
#  [4.764705882352928, -0.53, 53.16],
#  [1.941176470588232, 0.26, -91.74],
#  [-1.588235294117652, -0.28, -84.9],
#  [-3.0, -1.49, -14.19],
#  [-0.8823529411764639, 1.06, 69.73],
#  [1.941176470588232, 0.77, -141.32],
#  [0.529411764705884, 0.32, -101.64],
#  [-2.2941176470588402, -0.15, 89.51],
#  [5.470588235294116, -0.51, 89.06],
#  [4.058823529411768, 0.15, -94.09],
#  [-4.411764705882348, -1.68, -17.81],
#  [-5.117647058823536, 0.0, 67.57],
#  [-3.0, 0.38, 59.45],
#  [-2.2941176470588402, -1.18, -79.99],
#  [-3.705882352941188, -0.42, 95.45],
#  [2.6470588235293917, -0.57, 59.56],
#  [-0.17647058823530415, 0.68, 54.44],
#  [1.2352941176470722, -1.09, -75.22],
#  [1.2352941176470722, -0.74, 36.96],
#  [-4.411764705882348, -0.5, -70.31],
#  [-4.411764705882348, -0.41, 55.31],
#  [1.2352941176470722, -1.1, -95.31],
#  [-3.0, -0.31, -80.03],
#  [2.6470588235293917, -1.05, -54.41],
#  [4.764705882352928, -0.23, 91.82],
#  [4.058823529411768, -0.52, 87.63],
#  [1.2352941176470722, 0.06, 81.52],
#  [-1.588235294117652, 0.42, 31.19],
#  [-3.705882352941188, -2.51, -15.07],
#  [1.2352941176470722, -0.95, -85.68],
#  [-0.17647058823530415, -0.78, 32.93],
#  [-4.411764705882348, 0.14, -79.64],
#  [-2.2941176470588402, -0.65, -13.87],
#  [3.35294117647058, -0.13, 77.68],
#  [-3.705882352941188, -0.49, -99.48],
#  [-0.17647058823530415, -0.8, 28.19],
#  [4.058823529411768, 0.01, -64.96],
#  [1.941176470588232, 0.22, -82.89],
#  [2.6470588235293917, -0.13, 64.99],
#  [-0.8823529411764639, -1.16, -90.09],
#  [-3.705882352941188, -0.82, 89.21],
#  [3.35294117647058, 0.16, -153.49],
#  [-0.8823529411764639, -0.09, 52.74],
#  [3.35294117647058, -0.64, -13.84],
#  [0.529411764705884, -0.62, -62.46],
#  [-0.17647058823530415, 0.51, 73.95],
#  [-0.8823529411764639, 0.03, -87.4],
#  [-0.8823529411764639, 0.22, 72.37],
#  [-3.0, -0.34, 94.01],
#  [2.6470588235293917, -0.65, -54.56],
#  [-0.8823529411764639, -1.38, -69.83],
#  [0.529411764705884, -0.21, 86.55],
#  [1.941176470588232, -0.44, -15.17],
#  [-0.17647058823530415, -1.12, -13.52],
#  [-4.411764705882348, -1.07, -75.05],
#  [1.2352941176470722, -0.97, -67.14],
#  [-1.588235294117652, -0.99, -150.23],
#  [-0.17647058823530415, 0.69, 65.38],
#  [-3.0, -0.64, -12.85],
#  [-3.705882352941188, -0.69, 29.08],
#  [-3.705882352941188, -1.35, 66.93],
#  [1.2352941176470722, 0.54, 44.12],
#  [-0.8823529411764639, -1.52, -13.03],
#  [-4.411764705882348, -0.0, 75.23],
#  [-0.8823529411764639, 0.56, 84.63],
#  [-0.17647058823530415, -1.0, -74.5],
#  [-0.8823529411764639, -0.82, -78.31],
#  [-5.117647058823536, 0.03, 58.5],
#  [-0.8823529411764639, -1.0, -66.12],
#  [1.941176470588232, -0.05, 84.51],
#  [-0.8823529411764639, -0.34, 79.9],
#  [-0.17647058823530415, -0.32, -91.6],
#  [1.2352941176470722, -0.66, 30.09],
#  [-2.2941176470588402, -1.07, -72.83],
#  [-3.705882352941188, -0.49, 30.72],
#  [-3.0, -0.89, 54.75],
#  [-3.0, -1.47, 76.05],
#  [1.941176470588232, -1.14, 85.94],
#  [-5.117647058823536, -0.22, -129.23],
#  [3.35294117647058, -0.18, 32.33],
#  [-5.823529411764696, -1.23, -53.1],
#  [-3.705882352941188, -1.55, -143.39],
#  [-0.8823529411764639, -1.18, -92.23],
#  [-3.705882352941188, -0.79, 65.27],
#  [-0.8823529411764639, -1.91, -15.79],
#  [2.6470588235293917, -0.8, 67.75],
#  [-2.2941176470588402, -1.29, -85.73],
#  [-2.2941176470588402, 0.05, 54.52],
#  [1.2352941176470722, -0.56, -66.67],
#  [-1.588235294117652, -0.44, 59.73],
#  [-1.588235294117652, -1.56, -15.83],
#  [1.941176470588232, -0.56, -43.65],
#  [2.6470588235293917, -0.11, 74.31],
#  [-4.411764705882348, -0.43, 86.09],
#  [-3.705882352941188, -0.93, -82.93],
#  [-3.0, 0.17, -98.42],
#  [-0.8823529411764639, -0.72, 36.93],
#  [-3.705882352941188, -0.49, 65.42],
#  [-0.17647058823530415, -0.83, 31.2],
#  [-0.17647058823530415, 0.16, -149.31],
#  [-2.2941176470588402, 0.84, 32.15],
#  [-5.117647058823536, -1.35, 35.44],
#  [-0.8823529411764639, -0.65, 29.35],
#  [-3.705882352941188, 0.06, 41.73],
#  [0.529411764705884, -0.87, 29.97],
#  [-1.588235294117652, -1.44, -81.86],
#  [4.058823529411768, 0.39, 78.18],
#  [1.2352941176470722, 0.28, -84.41],
#  [0.529411764705884, -0.94, -85.5],
#  [2.6470588235293917, -1.11, -80.26],
#  [-0.8823529411764639, -0.19, -113.82],
#  [-3.0, -1.01, 83.67],
#  [0.529411764705884, -1.37, -102.9],
#  [-1.588235294117652, -1.46, -14.13],
#  [0.529411764705884, -0.66, -60.54],
#  [-2.2941176470588402, -0.73, 76.78],
#  [-1.588235294117652, -0.52, -79.51],
#  [-0.17647058823530415, -1.4, -68.22],
#  [-0.17647058823530415, -0.61, -63.02],
#  [-0.17647058823530415, -1.32, 92.93],
#  [-4.411764705882348, -0.09, 58.73],
#  [4.764705882352928, -0.56, -148.5],
#  [1.2352941176470722, 0.08, 28.58],
#  [2.6470588235293917, -0.72, 62.66],
#  [-3.705882352941188, -1.22, 36.3],
#  [1.2352941176470722, -0.53, 86.6],
#  [1.2352941176470722, -0.87, -68.67],
#  [-0.8823529411764639, 0.07, 94.69],
#  [-1.588235294117652, -1.05, 31.63],
#  [1.941176470588232, -0.99, -59.39],
#  [-0.17647058823530415, -0.57, 30.65],
#  [-1.588235294117652, 0.1, -91.67],
#  [2.6470588235293917, -0.47, 31.55],
#  [-0.8823529411764639, -0.48, 55.54],
#  [0.529411764705884, -0.89, 35.72],
#  [1.2352941176470722, -0.03, -89.41],
#  [-3.0, -1.03, 84.45],
#  [-1.588235294117652, -1.45, 29.23],
#  [-0.8823529411764639, 0.43, 31.37],
#  [0.529411764705884, -0.46, -119.32],
#  [-3.0, -1.96, -70.04],
#  [5.470588235294116, 0.17, -97.4],
#  [-3.705882352941188, 0.51, 51.57],
#  [-5.823529411764696, -1.54, -15.86],
#  [-2.2941176470588402, -1.27, -69.91],
#  [-0.8823529411764639, 0.21, -78.08],
#  [5.470588235294116, 0.32, 89.78],
#  [-5.117647058823536, -0.78, 118.42],
#  [-0.17647058823530415, 0.14, 31.0],
#  [0.529411764705884, 0.0, -18.29],
#  [-5.117647058823536, -0.57, -41.53],
#  [-4.411764705882348, -0.18, 31.17],
#  [4.058823529411768, 0.94, 32.31],
#  [-5.117647058823536, -1.02, -14.19],
#  [1.941176470588232, -0.36, 54.44],
#  [4.764705882352928, -1.06, -81.66],
#  [-0.8823529411764639, 0.36, 44.93],
#  [-0.17647058823530415, 0.03, 48.73],
#  [-0.8823529411764639, -0.11, 40.26]]

# %%
df_o1_d02 = pd.DataFrame(biases_o1_d02)
df_o1_d02['condition']='1_02'
df_o1_d02['order']=1
df_o1_d02['delay']=0.2
df_o1_d02.columns=['interference', 'bias_target', 'bias_dist', 'condition', 'order', 'delay']


df_o1_d7 = pd.DataFrame(biases_o1_d7)
df_o1_d7['condition']='1_7'
df_o1_d7['order']=1
df_o1_d7['delay']=7
df_o1_d7.columns=['interference', 'bias_target', 'bias_dist', 'condition', 'order', 'delay']

df_o2_d02 = pd.DataFrame(biases_o2_d02)
df_o2_d02['condition']='2_02'
df_o2_d02['order']=2
df_o2_d02['delay']=0.2
df_o2_d02.columns=['interference', 'bias_target', 'bias_dist', 'condition', 'order', 'delay']


df_o2_d7 = pd.DataFrame(biases_o2_d7)
df_o2_d7['condition']='2_7'
df_o2_d7['order']=2
df_o2_d7['delay']=7
df_o2_d7.columns=['interference', 'bias_target', 'bias_dist', 'condition', 'order', 'delay']

df_all = pd.concat([df_o1_d02, df_o1_d7, df_o2_d02, df_o2_d7])
##df_all.to_excel('simul_far_4.xlsx')
# Out:
#      interference  bias_target  bias_dist condition  order  delay
# 0       -4.411765        -5.74      -3.94      1_02      1    0.2
# 1       -5.117647        -5.29      -2.77      1_02      1    0.2
# 2       -8.647059        -6.45      -3.09      1_02      1    0.2
# 3       -5.823529        -7.25      -2.06      1_02      1    0.2
# 4       -6.529412        -7.64      -2.03      1_02      1    0.2
# 5       -8.647059        -7.52      -2.44      1_02      1    0.2
# 6       -3.000000        -5.25      -5.13      1_02      1    0.2
# 7       -5.823529        -5.33      -2.78      1_02      1    0.2
# 8       -4.411765        -6.14      -3.01      1_02      1    0.2
# 9       -4.411765        -7.27      -3.01      1_02      1    0.2
# 10      -3.705882        -4.37      -4.33      1_02      1    0.2
# 11      -4.411765        -5.12      -3.91      1_02      1    0.2
# 12      -3.705882        -5.71      -4.51      1_02      1    0.2
# 13      -8.647059        -6.45      -2.97      1_02      1    0.2
# 14      -6.529412        -6.66      -2.88      1_02      1    0.2
# 15     -10.764706        -8.36      -2.20      1_02      1    0.2
# 16      -5.117647        -5.15      -3.37      1_02      1    0.2
# 17      -4.411765        -5.76      -3.09      1_02      1    0.2
# 18      -7.235294        -5.76      -3.03      1_02      1    0.2
# 19      -3.000000        -5.98      -3.08      1_02      1    0.2
# 20      -7.235294        -6.99      -1.73      1_02      1    0.2
# 21      -4.411765        -5.94      -3.61      1_02      1    0.2
# 22      -3.705882        -6.41      -2.71      1_02      1    0.2
# 23     -10.058824        -8.35      -3.29      1_02      1    0.2
# 24      -9.352941        -5.44      -3.42      1_02      1    0.2
# 25      -7.235294        -6.02      -3.69      1_02      1    0.2
# 26      -6.529412        -6.99      -2.92      1_02      1    0.2
# 27      -7.235294        -6.87      -2.48      1_02      1    0.2
# 28      -7.235294        -7.12      -3.48      1_02      1    0.2
# 29      -5.117647        -7.36      -3.57      1_02      1    0.2
# ..            ...          ...        ...       ...    ...    ...
# 270      1.941176        -0.99     -59.39       2_7      2    7.0
# 271     -0.176471        -0.57      30.65       2_7      2    7.0
# 272     -1.588235         0.10     -91.67       2_7      2    7.0
# 273      2.647059        -0.47      31.55       2_7      2    7.0
# 274     -0.882353        -0.48      55.54       2_7      2    7.0
# 275      0.529412        -0.89      35.72       2_7      2    7.0
# 276      1.235294        -0.03     -89.41       2_7      2    7.0
# 277     -3.000000        -1.03      84.45       2_7      2    7.0
# 278     -1.588235        -1.45      29.23       2_7      2    7.0
# 279     -0.882353         0.43      31.37       2_7      2    7.0
# 280      0.529412        -0.46    -119.32       2_7      2    7.0
# 281     -3.000000        -1.96     -70.04       2_7      2    7.0
# 282      5.470588         0.17     -97.40       2_7      2    7.0
# 283     -3.705882         0.51      51.57       2_7      2    7.0
# 284     -5.823529        -1.54     -15.86       2_7      2    7.0
# 285     -2.294118        -1.27     -69.91       2_7      2    7.0
# 286     -0.882353         0.21     -78.08       2_7      2    7.0
# 287      5.470588         0.32      89.78       2_7      2    7.0
# 288     -5.117647        -0.78     118.42       2_7      2    7.0
# 289     -0.176471         0.14      31.00       2_7      2    7.0
# 290      0.529412         0.00     -18.29       2_7      2    7.0
# 291     -5.117647        -0.57     -41.53       2_7      2    7.0
# 292     -4.411765        -0.18      31.17       2_7      2    7.0
# 293      4.058824         0.94      32.31       2_7      2    7.0
# 294     -5.117647        -1.02     -14.19       2_7      2    7.0
# 295      1.941176        -0.36      54.44       2_7      2    7.0
# 296      4.764706        -1.06     -81.66       2_7      2    7.0
# 297     -0.882353         0.36      44.93       2_7      2    7.0
# 298     -0.176471         0.03      48.73       2_7      2    7.0
# 299     -0.882353        -0.11      40.26       2_7      2    7.0
#
# [1200 rows x 6 columns]

# %%
g = sns.factorplot(x="order", y="bias_target", hue='delay', ci=69, data=df_all,
                   kind='bar', palette='coolwarm', aspect=1.5)


sns.set_style('white')
plt.xlabel('order', fontsize=16)
plt.ylabel('interference', fontsize=16)
plt.ylim(-10,3)
#plt.xticks([0, 1], ['1', '2'], fontsize=14)

g.fig.suptitle('Simulations: Order & Delay', fontsize=20, x=0.5, weight='demibold')


plt.show(block=False)


import statsmodels.formula.api as smf
result = smf.ols(formula="bias_target ~ delay*order ", data=df_all).fit()
print(result.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            bias_target   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     4256.
# Date:                Tue, 08 Oct 2019   Prob (F-statistic):               0.00
# Time:                        15:35:38   Log-Likelihood:                -1262.3
# No. Observations:                1200   AIC:                             2533.
# Df Residuals:                    1196   BIC:                             2553.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -11.7455      0.092   -127.309      0.000     -11.926     -11.564
# delay           1.0741      0.019     57.649      0.000       1.038       1.111
# order           5.3732      0.058     92.085      0.000       5.259       5.488
# delay:order    -0.5003      0.012    -42.456      0.000      -0.523      -0.477
# ==============================================================================
# Omnibus:                        8.964   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               10.745
# Skew:                          -0.114   Prob(JB):                      0.00464
# Kurtosis:                       3.403   Cond. No.                         50.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from linares_plot import *

linares_plot(x="order", y="interference", hue='delay', df=df_all, order=[1,2],
             point_size=4, hue_order=[0.2,7], palette='coolwarm')


sns.set_style('white')
plt.xlabel('order', fontsize=16)
plt.ylabel('interference', fontsize=16)
plt.ylim(-15,8);
#plt.xticks([0, 1], ['1', '2'], fontsize=14)
