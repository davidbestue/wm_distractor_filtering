# %% [markdown]
# ## Analysis fMRI behaviour

# %%
# %matplotlib inline
#%config InlineBackend.figure_format = 'svg'

import os
import pandas as pd

# %run "C:\\Users\\David\\Documents\\GitHub\\wm_distractor_filtering\\psychophysics\\Funciones.ipynb"

#data_psychophysics_corrected
df = pd.read_csv('C:\\Users\\David\\Dropbox\\KAROLINSKA\\fMRI_beh_analysis\\behaviour_fMRI')


from numpy import loadtxt, shape, array, zeros, delete, argsort, mean, std, unique
import itertools
from itertools import chain
import matplotlib.pyplot as plt
import pickle
from pickle import *
import statsmodels.formula.api as sm
from scipy.stats import norm, ttest_1samp
import seaborn as sns
from scipy.stats import norm, ttest_1samp
from numpy import polyfit, poly1d
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
from scikits.bootstrap import ci
import ptitprince as pt

# %%
df_analysis = df[[ 'A_err',  'Interference', 'A_R', 'A_err_abs', 'delay', 'distance', 'subject',
                  'order', 'orient', 'type', 'A_dist', 'A_T',  'A_err_int_theoretical', 'A_res', 'A_err_theoretical' ]]

df.columns
# Out:
# Index(['Unnamed: 0', 'A_DC', 'A_DC_dis', 'A_DF', 'A_DF_dist', 'A_DVF',
#        'A_DVF_dist', 'A_NT1', 'A_NT1_dist', 'A_NT2', 'A_NT2_dist', 'A_T',
#        'A_dist', 'A_err', 'A_err_abs', 'A_err_int_theoretical', 'A_res',
#        'Q_DC', 'Q_DF', 'Q_DVF', 'Q_DVF_dist', 'RT', 'att_cue_time', 'cue_resp',
#        'delay', 'delay2', 'disp_time', 'dist_time', 'distance',
#        'horiz_vertical', 'order', 'orient', 'probe_time', 'session', 'subject',
#        'target_time', 'trial_time', 'type', 'A_err_theoretical',
#        'theoretical_dist', 'A_err_raw', 'Interference_raw', 'Interference',
#        'A_R'],
#       dtype='object')

# %%
df_analysis = df_analysis.loc[df_analysis['type']!=4]
df_analysis.rename(columns={'orient': 'cond'}, inplace=True)
df_analysis['cw_ccw']=[cw_ccw_detector(df_analysis['A_T'].iloc[i], df_analysis['A_dist'].iloc[i]) for i in range(0, len(df_analysis))]

df_analysis['Interference_col'] = df_analysis['A_err'].copy()
df_analysis.loc[df_analysis['cw_ccw']=='cw', 'Interference_col'] = df_analysis.loc[df_analysis['cw_ccw']=='cw', 'Interference_col']*-1

df_analysis['sex']=[male_female(df_analysis['subject'].loc[ind]) for ind in df_analysis.index]

#In case you want to try other alternatives
#df_analysis.rename(columns={'A_err_theoretical': 'A_err'}, inplace=True)
#df_analysis.rename(columns={'A_err_jh': 'A_err'}, inplace=True)

#correction of the types 1: <20, 2: 20-30, 3: >30
for i in df_analysis.index:
    if df_analysis.loc[i].distance <20 :
        t =1
    elif df_analysis.loc[i].distance >30 :
        t =3
    else:
        t=2
    
    #print(t)
    df_analysis.loc[i, 'type'] = t



df_analysis['dist_in_out'] = df_analysis['type'].copy() 
df_analysis['dist_in_out'] = df_analysis['dist_in_out'].replace([1 ,2, 3], ['in', 'in', 'out'])



df_analysis['ord_del_cond'] = df_analysis[['delay','order']].sum(axis=1)
df_analysis['ord_del_cond'] = df_analysis['ord_del_cond'].replace([1.2, 2.2, 8, 9], ['1_d02', '2_d02', '1_d7', '2_d7'])

# %%
##### MEAN OF CW AND CCW COLLAPSING IN 

means_cw={}

for Subj in df_analysis.subject.unique():
    d_subj = df_analysis.groupby('subject').get_group(Subj)
    for ori in ['cw', 'ccw']:
        for Dist in df_analysis.dist_in_out.unique():
            for Cond_4 in df_analysis.ord_del_cond.unique():
                mean_cw = round(d_subj.loc[ (d_subj['cw_ccw']==ori)  & (d_subj['ord_del_cond']==Cond_4) &
                                           (d_subj['dist_in_out']==Dist), 'A_err_theoretical'   ].mean(), 3)
                means_cw[str(Subj)  + '_' + str(Cond_4) + '_' + str(Dist) + '_' + ori] = mean_cw
                

        
cw_ccw_distance=[]

for i in df_analysis.index:
    or_ = df_analysis.loc[i, 'cw_ccw']
    if or_ == 'cw':
        or_cont = 'ccw'
    elif or_ =='ccw':
        or_cont = 'cw' 
    else:
        print('Error')
    idx =  str(df_analysis.loc[i, 'subject'])+ '_' + df_analysis.loc[i, 'ord_del_cond'] +'_' + df_analysis.loc[i, 'dist_in_out'] + '_'+ or_cont
    #
    if or_ == 'ccw':
        cw_ccw_distance.append(df_analysis.loc[i, 'A_err_theoretical'] - means_cw[idx] )  
    elif or_ =='cw':
        cw_ccw_distance.append( means_cw[idx] - df_analysis.loc[i, 'A_err_theoretical'])  
    else:
        print('Error')
    


df_analysis['distance_A_err'] = cw_ccw_distance

# %%
### SUBJECT BY SUBJECT

for SUBJ in df_analysis.subject.unique():
    df_subj = df_analysis.loc[df_analysis['subject']==SUBJ]
    #Plot of errors
    fig = plt.figure()
    fig.set_size_inches(15, 5)
    fig.tight_layout()
    fig.suptitle('Subject ' +str(SUBJ))
    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)
    sns.barplot(ax=ax1, x="type", y="Interference", hue='ord_del_cond', hue_order=['1_d02',  '1_d7', '2_d02', '2_d7'], 
                data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

    sns.barplot(ax=ax2, x="type", y="distance_A_err", hue='ord_del_cond', hue_order=['1_d02',  '1_d7', '2_d02', '2_d7'],
                data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

    sns.barplot( ax=ax3, x="type", y="A_err_abs", hue='ord_del_cond', hue_order=['1_d02',  '1_d7', '2_d02', '2_d7'],
                data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])



    axes=[ax1, ax2, ax3]
    Titles=['Interference', 'Distance cw ccw', 'Absolute']

    for i, Ax in enumerate(axes):
        Ax.spines['right'].set_visible(False)
        Ax.spines['top'].set_visible(False)
        Ax.title.set_text(Titles[i])
        Ax.legend_.remove()
        Ax.set_xticklabels(['10-20', '>30'])
        Ax.set_xlabel('Distance T-Dist')
        Ax.set_ylabel('')


    ax2.legend(loc=3)
    ax1.set_ylabel('value')
    plt.show()
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
### SUBJECT BY SUBJECT

for SUBJ in df_analysis.subject.unique():
    df_subj = df_analysis.loc[df_analysis['subject']==SUBJ]
    #Plot of errors
    fig = plt.figure()
    fig.set_size_inches(15, 5)
    fig.tight_layout()
    fig.suptitle('Subject ' +str(SUBJ))
    ax1 = fig.add_subplot(131)
    ax2 = fig.add_subplot(132)
    ax3 = fig.add_subplot(133)
    sns.barplot(ax=ax1, x="dist_in_out", y="Interference", hue='ord_del_cond', hue_order=['1_d02',  '1_d7', '2_d02', '2_d7'], 
                data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

    sns.barplot(ax=ax2, x="dist_in_out", y="distance_A_err", hue='ord_del_cond', hue_order=['1_d02',  '1_d7', '2_d02', '2_d7'],
                data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

    #sns.barplot( ax=ax3, x="dist_in_out", y="A_err_abs", hue='ord_del_cond', hue_order=['1_d02',  '1_d7', '2_d02', '2_d7'],
    #            data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

    sns.barplot( ax=ax3, x="ord_del_cond", y="A_err_abs", order=['1_d02',  '1_d7', '2_d02', '2_d7'],
                data=df_subj, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

    axes=[ax1, ax2, ax3]
    Titles=['Interference', 'Distance cw ccw', 'Absolute']

    for i, Ax in enumerate(axes):
        Ax.spines['right'].set_visible(False)
        Ax.spines['top'].set_visible(False)
        Ax.title.set_text(Titles[i])
        #Ax.legend_.remove()
        Ax.set_xticklabels(['in','out'])
        Ax.set_xlabel('Distance T-Dist')
        Ax.set_ylabel('')


    ax2.legend(loc=3)
    ax1.set_ylabel('value')
    plt.show()
    
    Precision = round(df_subj.A_err_abs.mean(), 3)
    Interference = round(df_subj.Interference.mean(), 3)
    print( 'Precision ' + str(SUBJ) +  ' = ' + str(Precision))
    print( 'Interference ' + str(SUBJ) +  ' = ' + str(Interference))
    result = smf.ols(formula="distance_A_err ~ delay*order*dist_in_out ", data=df_subj).fit()
    print(result.summary())
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Precision 26.0 = 8.548
# Interference 26.0 = 0.901
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         distance_A_err   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     5.298
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           1.11e-05
# Time:                        15:21:40   Log-Likelihood:                -1010.4
# No. Observations:                 272   AIC:                             2037.
# Df Residuals:                     264   BIC:                             2066.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         21.7689      3.859      5.642      0.000      14.171      29.366
# dist_in_out[T.out]               -23.7748      5.464     -4.351      0.000     -34.534     -13.016
# delay                             -3.6091      0.826     -4.370      0.000      -5.235      -1.983
# delay:dist_in_out[T.out]           3.0667      1.159      2.646      0.009       0.785       5.349
# order                            -11.4318      2.430     -4.704      0.000     -16.217      -6.646
# order:dist_in_out[T.out]          14.5876      3.449      4.230      0.000       7.797      21.378
# delay:order                        2.2987      0.513      4.478      0.000       1.288       3.309
# delay:order:dist_in_out[T.out]    -2.2267      0.722     -3.083      0.002      -3.649      -0.805
# ==============================================================================
# Omnibus:                        4.495   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                3.021
# Skew:                          -0.071   Prob(JB):                        0.221
# Kurtosis:                       2.503   Cond. No.                         127.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Precision 27.0 = 11.662
# Interference 27.0 = 0.63
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         distance_A_err   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     6.315
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           6.28e-07
# Time:                        15:21:41   Log-Likelihood:                -1233.3
# No. Observations:                 308   AIC:                             2483.
# Df Residuals:                     300   BIC:                             2513.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -2.5269      4.934     -0.512      0.609     -12.236       7.182
# dist_in_out[T.out]                 3.8303      6.916      0.554      0.580      -9.780      17.441
# delay                             -2.7793      1.044     -2.661      0.008      -4.834      -0.724
# delay:dist_in_out[T.out]           2.1632      1.439      1.503      0.134      -0.669       4.995
# order                              3.1289      3.097      1.010      0.313      -2.966       9.224
# order:dist_in_out[T.out]          -2.2283      4.366     -0.510      0.610     -10.820       6.363
# delay:order                        1.6344      0.651      2.512      0.013       0.354       2.915
# delay:order:dist_in_out[T.out]    -0.6535      0.904     -0.723      0.470      -2.432       1.125
# ==============================================================================
# Omnibus:                        4.425   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.109   Jarque-Bera (JB):                2.985
# Skew:                          -0.041   Prob(JB):                        0.225
# Kurtosis:                       2.525   Cond. No.                         129.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Precision 22.0 = 6.944
# Interference 22.0 = 0.395
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         distance_A_err   R-squared:                       0.320
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     23.25
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           7.92e-26
# Time:                        15:21:41   Log-Likelihood:                -1228.1
# No. Observations:                 354   AIC:                             2472.
# Df Residuals:                     346   BIC:                             2503.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         10.1437      2.674      3.793      0.000       4.884      15.403
# dist_in_out[T.out]               -20.0777      3.820     -5.256      0.000     -27.591     -12.564
# delay                              0.4297      0.544      0.790      0.430      -0.641       1.500
# delay:dist_in_out[T.out]           2.1371      0.780      2.739      0.006       0.603       3.672
# order                             -2.5250      1.697     -1.488      0.138      -5.862       0.812
# order:dist_in_out[T.out]           5.6582      2.420      2.338      0.020       0.899      10.418
# delay:order                       -0.4791      0.344     -1.394      0.164      -1.155       0.197
# delay:order:dist_in_out[T.out]    -0.9628      0.492     -1.958      0.051      -1.930       0.004
# ==============================================================================
# Omnibus:                        5.505   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.064   Jarque-Bera (JB):                3.539
# Skew:                          -0.026   Prob(JB):                        0.170
# Kurtosis:                       2.513   Cond. No.                         130.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Precision 23.0 = 6.794
# Interference 23.0 = 0.099
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         distance_A_err   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     2.456
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):             0.0180
# Time:                        15:21:42   Log-Likelihood:                -1238.4
# No. Observations:                 354   AIC:                             2493.
# Df Residuals:                     346   BIC:                             2524.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          6.6306      2.823      2.349      0.019       1.079      12.182
# dist_in_out[T.out]                -4.6661      3.941     -1.184      0.237     -12.417       3.085
# delay                             -0.2913      0.568     -0.513      0.608      -1.408       0.826
# delay:dist_in_out[T.out]           0.2470      0.798      0.310      0.757      -1.322       1.816
# order                             -3.8122      1.767     -2.157      0.032      -7.288      -0.336
# order:dist_in_out[T.out]           2.6949      2.501      1.078      0.282      -2.224       7.613
# delay:order                       -0.0454      0.357     -0.127      0.899      -0.747       0.656
# delay:order:dist_in_out[T.out]     0.1480      0.506      0.292      0.770      -0.848       1.144
# ==============================================================================
# Omnibus:                        2.030   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.362   Jarque-Bera (JB):                1.896
# Skew:                          -0.096   Prob(JB):                        0.388
# Kurtosis:                       2.698   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Precision 24.0 = 7.452
# Interference 24.0 = -0.65
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         distance_A_err   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     6.112
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):           1.15e-06
# Time:                        15:21:43   Log-Likelihood:                -1058.3
# No. Observations:                 294   AIC:                             2133.
# Df Residuals:                     286   BIC:                             2162.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -4.3923      3.514     -1.250      0.212     -11.310       2.525
# dist_in_out[T.out]                -3.8427      4.909     -0.783      0.434     -13.505       5.819
# delay                             -0.6018      0.698     -0.862      0.390      -1.977       0.773
# delay:dist_in_out[T.out]           4.2251      0.977      4.325      0.000       2.302       6.148
# order                              2.2505      2.242      1.004      0.316      -2.163       6.664
# order:dist_in_out[T.out]           2.3620      3.138      0.753      0.452      -3.815       8.539
# delay:order                        0.2411      0.440      0.548      0.584      -0.625       1.107
# delay:order:dist_in_out[T.out]    -2.5133      0.617     -4.071      0.000      -3.728      -1.298
# ==============================================================================
# Omnibus:                        3.519   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.172   Jarque-Bera (JB):                2.523
# Skew:                          -0.040   Prob(JB):                        0.283
# Kurtosis:                       2.553   Cond. No.                         141.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Precision 25.0 = 8.39
# Interference 25.0 = 0.18
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         distance_A_err   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     3.316
# Date:                Tue, 09 Apr 2019   Prob (F-statistic):            0.00205
# Time:                        15:21:44   Log-Likelihood:                -1136.4
# No. Observations:                 305   AIC:                             2289.
# Df Residuals:                     297   BIC:                             2319.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -7.8102      3.784     -2.064      0.040     -15.256      -0.364
# dist_in_out[T.out]                 0.9266      5.330      0.174      0.862      -9.562      11.415
# delay                              1.4476      0.792      1.829      0.068      -0.110       3.005
# delay:dist_in_out[T.out]          -1.8059      1.099     -1.643      0.102      -3.970       0.358
# order                              4.6577      2.375      1.961      0.051      -0.016       9.331
# order:dist_in_out[T.out]           1.6224      3.358      0.483      0.629      -4.986       8.230
# delay:order                       -0.8398      0.490     -1.715      0.087      -1.803       0.124
# delay:order:dist_in_out[T.out]     0.6756      0.687      0.983      0.326      -0.677       2.028
# ==============================================================================
# Omnibus:                       11.317   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                5.500
# Skew:                           0.037   Prob(JB):                       0.0639
# Kurtosis:                       2.346   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.barplot(x="ord_del_cond", y="A_err_abs", order=['1_d02',  '1_d7', '2_d02', '2_d7'],
                data=df_analysis, palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_analysis['subject'] = df_analysis['subject'].replace([22, 23, 24, 25, 26, 27], ['n001', 'b001', 'l001', 's001', 'r001', 'd001'])
sns.barplot(x="subject", y="A_err_abs", order=['n001', 'd001' , 'r001', 'b001', 'l001', 's001' ], data=df_analysis)
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#### ALL TOGETHER SUMMARY

fig = plt.figure()
fig.set_size_inches(15, 5)
fig.tight_layout()
fig.suptitle('Order delay distance')
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
sns.barplot( ax= ax1, x="order", y="distance_A_err", hue='delay', data=df_analysis.loc[df_analysis['dist_in_out']=='in'], palette='Blues')
sns.barplot( ax= ax2, x="order", y="distance_A_err", hue='delay', data=df_analysis.loc[df_analysis['dist_in_out']=='out'], palette='Reds')
axes=[ax1, ax2]
Titles=['In', 'Out']

for i, Ax in enumerate(axes):
    Ax.spines['right'].set_visible(False)
    Ax.spines['top'].set_visible(False)
    Ax.title.set_text(Titles[i])
    #Ax.legend_.remove()
    #Ax.set_xticklabels(['in','out'])
    #Ax.set_xlabel('Distance T-Dist')
    Ax.set_ylabel('distance cw ccw')
    Ax.set_ylim(-8,8)

    
    
result = smf.mixedlm(formula="distance_A_err ~ delay*order*dist_in_out ", data=df_analysis, groups='subject').fit()
print(result.summary())

plt.show()


# result = smf.mixedlm(formula="distance_A_err ~ delay*order + delay*dist_in_out + order*dist_in_out ", data=df_analysis, groups='subject').fit()
# print(result.summary())


result = smf.mixedlm(formula="distance_A_err ~ delay*order ", data=df_analysis.loc[ df_analysis['dist_in_out']=='in'], groups='subject').fit()
print(result.summary())


result = smf.mixedlm(formula="distance_A_err ~ delay*order ", data=df_analysis.loc[df_analysis['dist_in_out']=='out'], groups='subject').fit()
print(result.summary())


# result = smf.mixedlm(formula="distance_A_err ~ delay + order ", data=df_analysis.loc[ df_analysis['dist_in_out']=='in'], groups='subject').fit()
# print(result.summary())


# result = smf.mixedlm(formula="distance_A_err ~ delay + order ", data=df_analysis.loc[df_analysis['dist_in_out']=='out'], groups='subject').fit()
# print(result.summary())
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                  MixedLM     Dependent Variable:     distance_A_err
# No. Observations:       1887        Method:                 REML
# No. Groups:             6           Scale:                  109.6534
# Min. group size:        272         Likelihood:             -7114.3466
# Max. group size:        354         Converged:              Yes
# Mean group size:        314.5
# --------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# --------------------------------------------------------------------------
# Intercept                       4.201    1.707  2.461 0.014   0.855  7.547
# dist_in_out[T.out]             -8.046    2.201 -3.655 0.000 -12.361 -3.732
# delay                          -0.768    0.322 -2.387 0.017  -1.398 -0.137
# delay:dist_in_out[T.out]        1.599    0.451  3.544 0.000   0.715  2.483
# order                          -1.369    0.986 -1.389 0.165  -3.300  0.563
# order:dist_in_out[T.out]        4.053    1.394  2.908 0.004   1.321  6.785
# delay:order                     0.382    0.201  1.898 0.058  -0.012  0.777
# delay:order:dist_in_out[T.out] -0.863    0.284 -3.041 0.002  -1.419 -0.307
# subject Var                     2.822    0.193
# ==========================================================================
#            Mixed Linear Model Regression Results
# ============================================================
# Model:            MixedLM Dependent Variable: distance_A_err
# No. Observations: 939     Method:             REML
# No. Groups:       6       Scale:              105.2858
# Min. group size:  135     Likelihood:         -3524.5598
# Max. group size:  181     Converged:          Yes
# Mean group size:  156.5
# -------------------------------------------------------------
#               Coef.   Std.Err.    z     P>|z|  [0.025  0.975]
# -------------------------------------------------------------
# Intercept      4.056     1.880   2.158  0.031   0.372   7.740
# delay         -0.773     0.315  -2.453  0.014  -1.391  -0.155
# order         -1.328     0.966  -1.375  0.169  -3.221   0.565
# delay:order    0.384     0.197   1.946  0.052  -0.003   0.770
# subject Var    7.117     0.481
# ============================================================
#
#            Mixed Linear Model Regression Results
# ============================================================
# Model:            MixedLM Dependent Variable: distance_A_err
# No. Observations: 948     Method:             REML
# No. Groups:       6       Scale:              104.6649
# Min. group size:  137     Likelihood:         -3556.0849
# Max. group size:  176     Converged:          Yes
# Mean group size:  158.0
# -------------------------------------------------------------
#               Coef.   Std.Err.    z     P>|z|  [0.025  0.975]
# -------------------------------------------------------------
# Intercept     -3.855     1.946  -1.981  0.048  -7.668  -0.042
# delay          0.820     0.309   2.653  0.008   0.214   1.425
# order          2.725     0.963   2.829  0.005   0.837   4.613
# delay:order   -0.477     0.196  -2.438  0.015  -0.860  -0.093
# subject Var    8.951     0.594
# ============================================================

# %%
order_cat = ['1_d02',  '1_d7', '2_d02', '2_d7']
df_analysis['ord_del_cond'] = pd.Categorical(df_analysis['ord_del_cond'], order_cat)

g = sns.factorplot(x="ord_del_cond", y="distance_A_err", data=df_analysis.loc[df_analysis['dist_in_out']=='in'],
                   kind='bar', palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])
sns.set_style('white')
g.set_axis_labels("Order", "distance_A_err")
g.set_xticklabels(['1','2'])
g.fig.suptitle('Order efects', fontsize=16, x=0.6, weight='demibold')
plt.show()

result = smf.mixedlm(formula="distance_A_err ~ ord_del_cond", data=df_analysis.loc[df_analysis['dist_in_out']=='in'], groups='subject').fit()
print(result.summary())
# Out:
# C:\Users\David\Anaconda2\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:              MixedLM  Dependent Variable:  distance_A_err
# No. Observations:   939      Method:              REML
# No. Groups:         6        Scale:               105.2858
# Min. group size:    135      Likelihood:          -3520.7260
# Max. group size:    181      Converged:           Yes
# Mean group size:    156.5
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              2.651    1.277  2.075 0.038  0.147  5.154
# ord_del_cond[T.1_d7]  -2.648    0.966 -2.742 0.006 -4.541 -0.755
# ord_del_cond[T.2_d02] -1.251    0.938 -1.334 0.182 -3.089  0.587
# ord_del_cond[T.2_d7]  -1.289    0.936 -1.376 0.169 -3.123  0.546
# subject Var            7.117    0.481
# ================================================================

# %%
fig = plt.figure()
fig.set_size_inches(15, 5)
fig.tight_layout()
fig.suptitle('Conditions with distance')
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

g = sns.factorplot(ax= ax1, x="ord_del_cond", y="distance_A_err", data=df_analysis.loc[df_analysis['dist_in_out']=='in'],
                   kind='bar', palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])


h= sns.factorplot(ax= ax2, x="ord_del_cond", y="distance_A_err", data=df_analysis.loc[df_analysis['dist_in_out']=='out'],
                   kind='bar', palette=['deepskyblue', 'saddlebrown', 'forestgreen','darkorange'])

plt.close()
plt.close()

axes=[ax1, ax2]
Titles=['In', 'Out']

for i, Ax in enumerate(axes):
    Ax.spines['right'].set_visible(False)
    Ax.spines['top'].set_visible(False)
    Ax.title.set_text(Titles[i])
    #Ax.legend_.remove()
    #Ax.set_xticklabels(['in','out'])
    Ax.set_xlabel('Conditions')
    Ax.set_ylabel('distance cw ccw')
    Ax.set_ylim(-7,7)


    
result = smf.mixedlm(formula="distance_A_err ~ ord_del_cond", data=df_analysis.loc[df_analysis['dist_in_out']=='in'], groups='subject').fit()
print(result.summary())  
    
result = smf.mixedlm(formula="distance_A_err ~ ord_del_cond", data=df_analysis.loc[df_analysis['dist_in_out']=='out'], groups='subject').fit()
print(result.summary())
# Out:
# C:\Users\David\Anaconda2\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\David\Anaconda2\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:              MixedLM  Dependent Variable:  distance_A_err
# No. Observations:   939      Method:              REML
# No. Groups:         6        Scale:               105.2858
# Min. group size:    135      Likelihood:          -3520.7260
# Max. group size:    181      Converged:           Yes
# Mean group size:    156.5
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              2.651    1.277  2.075 0.038  0.147  5.154
# ord_del_cond[T.1_d7]  -2.648    0.966 -2.742 0.006 -4.541 -0.755
# ord_del_cond[T.2_d02] -1.251    0.938 -1.334 0.182 -3.089  0.587
# ord_del_cond[T.2_d7]  -1.289    0.936 -1.376 0.169 -3.123  0.546
# subject Var            7.117    0.481
# ================================================================
#
#              Mixed Linear Model Regression Results
# ================================================================
# Model:              MixedLM  Dependent Variable:  distance_A_err
# No. Observations:   948      Method:              REML
# No. Groups:         6        Scale:               104.6649
# Min. group size:    137      Likelihood:          -3552.2511
# Max. group size:    176      Converged:           Yes
# Mean group size:    158.0
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept             -1.062    1.386 -0.766 0.444 -3.779  1.655
# ord_del_cond[T.1_d7]   2.334    0.939  2.485 0.013  0.493  4.175
# ord_del_cond[T.2_d02]  2.630    0.935  2.812 0.005  0.797  4.463
# ord_del_cond[T.2_d7]   1.723    0.932  1.848 0.065 -0.104  3.550
# subject Var            8.951    0.594
# ================================================================

# %%
#Plots summary

#### Distance
g = sns.factorplot(x="dist_in_out", y="distance_A_err", data=df_analysis,
                   kind='bar', palette='RdBu')

sns.set_style('white')
g.set_axis_labels("Distance", "distance_A_err")
g.set_xticklabels(['close','far'])
g.fig.suptitle('Distance efects', fontsize=16, x=0.6, weight='demibold')

plt.show()

result = smf.mixedlm(formula="distance_A_err ~ dist_in_out", data=df_analysis, groups='subject').fit()
print(result.summary())




df_analysis['distance_A_err_abs'] = df_analysis['distance_A_err'].copy()
df_analysis['distance_A_err_abs'] = abs(df_analysis['distance_A_err_abs'])



#### Order
g = sns.factorplot(x="order", y="distance_A_err_abs", data=df_analysis,
                   kind='bar', palette='RdBu')

sns.set_style('white')
g.set_axis_labels("order", "distance_A_err_abs")
g.set_xticklabels(['1','2'])
g.fig.suptitle('Order efects', fontsize=16, x=0.6, weight='demibold')

plt.show()

result = smf.mixedlm(formula="distance_A_err_abs ~ order", data=df_analysis, groups='subject').fit()
print(result.summary())



####  Delay
g = sns.factorplot(x="delay", y="distance_A_err_abs", data=df_analysis,
                   kind='bar', palette='RdBu')

sns.set_style('white')
g.set_axis_labels("Order", "distance cw ccw abs")
g.set_xticklabels(['0.2','7'])
g.fig.suptitle('Delay efects', fontsize=16, x=0.6, weight='demibold')

plt.show()

result = smf.mixedlm(formula="distance_A_err_abs ~ delay", data=df_analysis, groups='subject').fit()
print(result.summary())
# Out:
# C:\Users\David\Anaconda2\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
#             Mixed Linear Model Regression Results
# =============================================================
# Model:             MixedLM Dependent Variable: distance_A_err
# No. Observations:  1887    Method:             REML
# No. Groups:        6       Scale:              110.2418
# Min. group size:   272     Likelihood:         -7119.3524
# Max. group size:   354     Converged:          Yes
# Mean group size:   314.5
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           1.477    0.772  1.913 0.056 -0.036  2.990
# dist_in_out[T.out] -0.921    0.483 -1.905 0.057 -1.869  0.027
# subject Var         2.868    0.195
# =============================================================
# C:\Users\David\Anaconda2\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: distance_A_err_abs
# No. Observations: 1887    Method:             REML
# No. Groups:       6       Scale:              37.0497
# Min. group size:  272     Likelihood:         -6094.8985
# Max. group size:  354     Converged:          Yes
# Mean group size:  314.5
# ------------------------------------------------------------------
#               Coef.    Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      9.410      0.919   10.238   0.000    7.609   11.211
# order         -0.520      0.280   -1.856   0.063   -1.070    0.029
# subject Var    3.876      0.415
# ================================================================
# C:\Users\David\Anaconda2\envs\python3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: distance_A_err_abs
# No. Observations: 1887    Method:             REML
# No. Groups:       6       Scale:              37.0772
# Min. group size:  272     Likelihood:         -6097.4986
# Max. group size:  354     Converged:          Yes
# Mean group size:  314.5
# ------------------------------------------------------------------
#               Coef.    Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      8.836      0.826   10.691   0.000    7.216   10.455
# delay         -0.059      0.041   -1.441   0.150   -0.140    0.021
# subject Var    3.851      0.413
# ================================================================
